# %%
import pandas as pd
import numpy as np
import os
import json
import ijson
import pandas as pd
import pyarrow as pa
import pyarrow.parquet as pq
import gzip

# %%
yelp = pd.read_parquet(r'datasets\yelp\user-002.parquet')

# %%
yelp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2105597 entries, 0 to 2105596
# Data columns (total 22 columns):
#  #   Column              Dtype
# ---  ------              -----
#  0   user_id             object
#  1   name                object
#  2   review_count        int64
#  3   yelping_since       object
#  4   useful              int64
#  5   funny               int64
#  6   cool                int64
#  7   elite               object
#  8   friends             object
#  9   fans                int64
#  10  average_stars       float64
#  11  compliment_hot      int64
#  12  compliment_more     int64
#  13  compliment_profile  int64
#  14  compliment_cute     int64
#  15  compliment_list     int64
#  16  compliment_note     int64
#  17  compliment_plain    int64
#  18  compliment_cool     int64
#  19  compliment_funny    int64
#  20  compliment_writer   int64
#  21  compliment_photos   int64
# dtypes: float64(1), int64(16), object(5)
# memory usage: 353.4+ MB

# %%
yelp.head()
# Out:
#                   user_id    name  review_count        yelping_since  useful  \
# 0  qVc8ODYU5SZjKXVBgXdI7w  Walker           585  2007-01-25 16:47:26    7217
# 1  j14WgRoU_-2ZE1aw1dXrJg  Daniel          4333  2009-01-25 04:35:42   43091
# 2  2WnXYQFK0hXEoTxPtV2zvg   Steph           665  2008-07-25 10:41:00    2086
# 3  SZDeASXq7o05mMNLshsdIA    Gwen           224  2005-11-29 04:38:33     512
# 4  hA5lMy-EnncsH4JoR-hFGQ   Karen            79  2007-01-05 19:40:59      29
#
#    funny   cool                                              elite  \
# 0   1259   5994                                               2007
# 1  13066  27281  2009,2010,2011,2012,2013,2014,2015,2016,2017,2...
# 2   1010   1003                           2009,2010,2011,2012,2013
# 3    330    299                                     2009,2010,2011
# 4     15      7
#
#                                              friends  fans  ...  \
# 0  NSCy54eWehBJyZdG2iE84w, pe42u7DcCH2QmI81NX-8qA...   267  ...
# ...

# %% [markdown]
# ## Columnas eliminadas
#
# -review_count
#
# -funny
#
# -cool
#
# -fans
#
#
#
#  4   useful              int64
#  5   funny               int64
#  6   cool                int64
#  7   elite               object
#  8   friends             object
#  9   fans                int64
#  10  average_stars       float64
#  11  compliment_hot      int64
#  12  compliment_more     int64
#  13  compliment_profile  int64
#  14  compliment_cute     int64
#  15  compliment_list     int64
#  16  compliment_note     int64
#  17  compliment_plain    int64
#  18  compliment_cool     int64
#  19  compliment_funny    int64
#  20  compliment_writer   int64
#  21  compliment_photos   int64

# %%
pikle = pd.read_pickle(r'datasets\yelp\business.pkl')

# %%
pikle
# Out:
#                    business_id                      name  \
# 0       Pns2l4eNsfO8kk83dixA6A  Abby Rappoport, LAC, CMQ
# 1       mpf3x-BjTdTEA3yCZrAYPw             The UPS Store
# 2       tUFrWirKiKi_TAnsVWINQQ                    Target
# 3       MTSW4McQd7CbVtyjqoe9mw        St Honore Pastries
# 4       mWMc6_wTdE0EUBKIGXDVfA  Perkiomen Valley Brewery
# ...                        ...                       ...
# 150341  IUQopTMmYQG-qRtBk-8QnA              Binh's Nails
# 150342  c8GjPIOTGVmIemT7j5_SyQ      Wild Birds Unlimited
# 150343  _QAMST-NrQobXduilWEqSw         Claire's Boutique
# 150344  mtGm22y5c2UHNXDFAjaPNw  Cyclery & Fitness Center
# 150345  jV_XOycEzSlTx-65W906pg                   Sic Ink
#
#                                 address           city state postal_code  \
# 0                1616 Chapala St, Ste 2  Santa Barbara   NaN       93101
# 1       87 Grasso Plaza Shopping Center         Affton   NaN       63123
# ...

# %%
pikle_limpio = pikle[['business_id', 'name', 'latitude', 'longitude', 'stars', 'categories']]

# %%
pikle.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 150346 entries, 0 to 150345
# Data columns (total 28 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   business_id   150346 non-null  object
#  1   name          150346 non-null  object
#  2   address       150346 non-null  object
#  3   city          150346 non-null  object
#  4   state         150343 non-null  object
#  5   postal_code   150346 non-null  object
#  6   latitude      150346 non-null  float64
#  7   longitude     150346 non-null  float64
#  8   stars         150346 non-null  object
#  9   review_count  150346 non-null  object
#  10  is_open       150346 non-null  object
#  11  attributes    136602 non-null  object
#  12  categories    150243 non-null  object
#  13  hours         127123 non-null  object
#  14  business_id   5 non-null       object
#  15  name          5 non-null       object
#  16  address       5 non-null       object
# ...

# %%
# Generar una lista de nombres de columna como números secuenciales
nombres_columnas_numericas = [str(i) for i in range(len(pikle_limpio.columns))]

# Asignar los nuevos nombres de columna al DataFrame
pikle_limpio.columns = nombres_columnas_numericas

# %%
pikle_limpio.drop(columns=['1','3','5','7','9','11'],inplace=True)
# Out:
# C:\Users\jonat\AppData\Local\Temp\ipykernel_7572\1760044411.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pikle_limpio.drop(columns=['1','3','5','7','9','11'],inplace=True)

# %%
pikle_limpio.columns = ['business_id', 'name', 'latitude', 'longitude', 'stars', 'categories']

# %%
pikle_limpio.drop(columns=['name'],inplace=True)
# Out:
# C:\Users\jonat\AppData\Local\Temp\ipykernel_7572\1914495259.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pikle_limpio.drop(columns=['name'],inplace=True)

# %%
pikle_limpio
# Out:
#                    business_id   latitude   longitude stars  \
# 0       Pns2l4eNsfO8kk83dixA6A  34.426679 -119.711197   5.0
# 1       mpf3x-BjTdTEA3yCZrAYPw  38.551126  -90.335695   3.0
# 2       tUFrWirKiKi_TAnsVWINQQ  32.223236 -110.880452   3.5
# 3       MTSW4McQd7CbVtyjqoe9mw  39.955505  -75.155564   4.0
# 4       mWMc6_wTdE0EUBKIGXDVfA  40.338183  -75.471659   4.5
# ...                        ...        ...         ...   ...
# 150341  IUQopTMmYQG-qRtBk-8QnA  53.468419 -113.492054   3.0
# 150342  c8GjPIOTGVmIemT7j5_SyQ  36.115118  -86.766925   4.0
# 150343  _QAMST-NrQobXduilWEqSw  39.908707  -86.065088   3.5
# 150344  mtGm22y5c2UHNXDFAjaPNw  38.782351  -89.950558   4.0
# 150345  jV_XOycEzSlTx-65W906pg  27.771002   -82.39491   4.5
#
#                                                categories
# 0       Doctors, Traditional Chinese Medicine, Naturop...
# 1       Shipping Centers, Local Services, Notaries, Ma...
# 2       Department Stores, Shopping, Fashion, Home & G...
# ...

# %%
import shutil

# Guardar el DataFrame como un archivo CSV
pikle_limpio.to_csv('datasets/yelp/business.csv', index=False)

# Ruta del archivo CSV
archivo_csv = 'datasets/yelp/business.csv'

# Ruta de destino para el archivo comprimido gzip
archivo_gzip = 'datasets/yelp/business.csv.gz'

# Comprimir el archivo CSV a gzip
with open(archivo_csv, 'rb') as f_in, gzip.open(archivo_gzip, 'wb') as f_out:
    shutil.copyfileobj(f_in, f_out)

# %%
limites_estados = {
    'Alabama': {
        'lat_min': 30.144420,
        'lat_max': 35.008028,
        'lon_min': -88.473227,
        'lon_max': -84.888246
    },
    'Alaska': {
        'lat_min': 51.214183,
        'lat_max': 71.538800,
        'lon_min': -179.148909,
        'lon_max': -129.977672
    },
    'Arizona': {
        'lat_min': 31.332177,
        'lat_max': 37.004259,
        'lon_min': -114.818268,
        'lon_max': -109.045223
    },
    'Arkansas': {
        'lat_min': 33.004106,
        'lat_max': 36.499600,
        'lon_min': -94.617917,
        'lon_max': -89.640677
    },
    'California': {
        'lat_min': 32.512131,
        'lat_max': 42.009518,
        'lon_min': -124.482003,
        'lon_max': -114.131211
    },
    'Colorado': {
        'lat_min': 36.993076,
        'lat_max': 41.003444,
        'lon_min': -109.045223,
        'lon_max': -102.041522
    },
    'Connecticut': {
        'lat_min': 40.966667,
        'lat_max': 42.050587,
        'lon_min': -73.727775,
        'lon_max': -71.786994
    },
    'Delaware': {
        'lat_min': 38.451013,
        'lat_max': 39.839007,
        'lon_min': -75.789749,
        'lon_max': -75.048939
    },
    'Florida': {
        'lat_min': 24.396308,
        'lat_max': 31.000969,
        'lon_min': -87.634938,
        'lon_max': -80.031362
    },
    'Georgia': {
        'lat_min': 30.357851,
        'lat_max': 35.000659,
        'lon_min': -85.605166,
        'lon_max': -80.840718
    },
    'Hawaii': {
        'lat_min': 18.865459,
        'lat_max': 28.517061,
        'lon_min': -178.334698,
        'lon_max': -154.806773
    },
    'Idaho': {
        'lat_min': 41.988180,
        'lat_max': 49.001146,
        'lon_min': -117.243027,
        'lon_max': -111.043564
    },
    'Illinois': {
        'lat_min': 36.970298,
        'lat_max': 42.508481,
        'lon_min': -91.512974,
        'lon_max': -87.494756
    },
    'Indiana': {
        'lat_min': 37.771742,
        'lat_max': 41.761368,
        'lon_min': -88.097889,
        'lon_max': -84.784580
    },
    'Iowa': {
        'lat_min': 40.375501,
        'lat_max': 43.501196,
        'lon_min': -96.639485,
        'lon_max': -90.140061
    },
    'Kansas': {
        'lat_min': 36.993080,
        'lat_max': 40.003166,
        'lon_min': -102.051744,
        'lon_max': -94.588413
    },
    'Kentucky': {
        'lat_min': 36.497129,
        'lat_max': 39.147359,
        'lon_min': -89.571509,
        'lon_max': -81.964971
    },
    'Louisiana': {
        'lat_min': 28.855128,
        'lat_max': 33.019544,
        'lon_min': -94.043557,
        'lon_max': -88.758389
    },
    'Maine': {
        'lat_min': 42.974266,
        'lat_max': 47.459855,
        'lon_min': -71.083924,
        'lon_max': -66.925506
    },
    'Maryland': {
        'lat_min': 37.911717,
        'lat_max': 39.723043,
        'lon_min': -79.487651,
        'lon_max': -75.039673
    },
    'Massachusetts': {
        'lat_min': 41.185218,
        'lat_max': 42.886589,
        'lon_min': -73.508142,
        'lon_max': -69.858861
    },
    'Michigan': {
        'lat_min': 41.696118,
        'lat_max': 48.238920,
        'lon_min': -90.418136,
        'lon_max': -82.122002
    },
    'Minnesota': {
        'lat_min': 43.499356,
        'lat_max': 49.384358,
        'lon_min': -97.239209,
        'lon_max': -89.491739
    },
    'Mississippi': {
        'lat_min': 30.173943,
        'lat_max': 34.996052,
        'lon_min': -91.655009,
        'lon_max': -88.097889
    },
    'Missouri': {
        'lat_min': 35.995683,
        'lat_max': 40.613640,
        'lon_min': -95.774704,
        'lon_max': -89.098843
    },
    'Montana': {
        'lat_min': 44.358221,
        'lat_max': 49.001146,
        'lon_min': -116.049834,
        'lon_max': -104.039648
    },
    'Nebraska': {
        'lat_min': 39.999998,
        'lat_max': 43.001708,
        'lon_min': -104.053514,
        'lon_max': -95.30829
    },
    'Nevada': {
        'lat_min': 35.001857,
        'lat_max': 42.002207,
        'lon_min': -120.005746,
        'lon_max': -114.039648
    },
    'New Hampshire': {
        'lat_min': 42.697857,
        'lat_max': 45.305476,
        'lon_min': -72.557247,
        'lon_max': -70.703921
    },
    'New Jersey': {
        'lat_min': 38.788657,
        'lat_max': 41.357423,
        'lon_min': -75.559614,
        'lon_max': -73.885051
    },
    'New Mexico': {
        'lat_min': 31.332177,
        'lat_max': 37.000229,
        'lon_min': -109.050173,
        'lon_max': -103.002003
    },
    'New York': {
        'lat_min': 40.477399,
        'lat_max': 45.015851,
        'lon_min': -79.762590,
        'lon_max': -71.856214
    },
    'North Carolina': {
        'lat_min': 33.842316,
        'lat_max': 36.588117,
        'lon_min': -84.321869,
        'lon_max': -75.400119
    },
    'North Dakota': {
        'lat_min': 45.935054,
        'lat_max': 49.000574,
        'lon_min': -104.049269,
        'lon_max': -96.554507
    },
    'Ohio': {
        'lat_min': 38.403202,
        'lat_max': 42.327132,
        'lon_min': -84.820159,
        'lon_max': -80.518693
    },
    'Oklahoma': {
        'lat_min': 33.615833,
        'lat_max': 37.002206,
        'lon_min': -103.002003,
        'lon_max': -94.431648
    },
    'Oregon': {
        'lat_min': 41.991794,
        'lat_max': 46.292035,
        'lon_min': -124.566244,
        'lon_max': -116.463260
    },
    'Pennsylvania': {
        'lat_min': 39.719801,
        'lat_max': 42.269079,
        'lon_min': -80.519851,
        'lon_max': -74.689517
    },
    'Rhode Island': {
        'lat_min': 41.146339,
        'lat_max': 42.018798,
        'lon_min': -71.862772,
        'lon_max': -71.12057
    },
    'South Carolina': {
        'lat_min': 32.033304,
        'lat_max': 35.215402,
        'lon_min': -83.353912,
        'lon_max': -78.499301
    },
    'South Dakota': {
        'lat_min': 42.479635,
        'lat_max': 45.94545,
        'lon_min': -104.057698,
        'lon_max': -96.436589
    },
    'Tennessee': {
        'lat_min': 34.982924,
        'lat_max': 36.678118,
        'lon_min': -90.310298,
        'lon_max': -81.6469
    },
    'Texas': {
        'lat_min': 25.837377,
        'lat_max': 36.500704,
        'lon_min': -106.645646,
        'lon_max': -93.507212
    },
    'Utah': {
        'lat_min': 36.997968,
        'lat_max': 42.001702,
        'lon_min': -114.053029,
        'lon_max': -109.041058
    },
    'Vermont': {
        'lat_min': 42.726853,
        'lat_max': 45.016659,
        'lon_min': -73.43774,
        'lon_max': -71.465052
    },
    'Virginia': {
        'lat_min': 36.540738,
        'lat_max': 39.466012,
        'lon_min': -83.67529,
        'lon_max': -75.16644
    },
    'Washington': {
        'lat_min': 45.543541,
        'lat_max': 49.002494,
        'lon_min': -124.848974,
        'lon_max': -116.916485
    },
    'West Virginia': {
        'lat_min': 37.201483,
        'lat_max': 40.638801,
        'lon_min': -82.644739,
        'lon_max': -77.719519
    },
    'Wisconsin': {
        'lat_min': 42.491983,
        'lat_max': 47.080621,
        'lon_min': -92.888114,
        'lon_max': -86.249548
    },
    'Wyoming': {
        'lat_min': 40.994746,
        'lat_max': 45.005904,
        'lon_min': -111.05562,
        'lon_max': -104.05216
    },
    'District_of_Columbia': {
        'lat_min': 38.791645,
        'lat_max': 38.995845,
        'lon_min': -77.119759,
        'lon_max': -76.909395
    }}

# %%
# Convertir el diccionario en un DataFrame y agregar un índice
df_limites_estados = pd.DataFrame.from_dict(limites_estados, orient='index').reset_index()

# Renombrar la columna 'index' como 'estado'
df_limites_estados = df_limites_estados.rename(columns={'index': 'estado'})

# %%
df_limites_estados.to_csv(r'estados.csv',index =False)

# %%
df_limites_estados
# Out:
#                   estado    lat_min    lat_max     lon_min     lon_max
# 0                Alabama  30.144420  35.008028  -88.473227  -84.888246
# 1                 Alaska  51.214183  71.538800 -179.148909 -129.977672
# 2                Arizona  31.332177  37.004259 -114.818268 -109.045223
# 3               Arkansas  33.004106  36.499600  -94.617917  -89.640677
# 4             California  32.512131  42.009518 -124.482003 -114.131211
# 5               Colorado  36.993076  41.003444 -109.045223 -102.041522
# 6            Connecticut  40.966667  42.050587  -73.727775  -71.786994
# 7               Delaware  38.451013  39.839007  -75.789749  -75.048939
# 8                Florida  24.396308  31.000969  -87.634938  -80.031362
# 9                Georgia  30.357851  35.000659  -85.605166  -80.840718
# 10                Hawaii  18.865459  28.517061 -178.334698 -154.806773
# 11                 Idaho  41.988180  49.001146 -117.243027 -111.043564
# ...

# %%
pikle['latitude'] = pikle['latitude'].astype(float)
pikle['longitude'] = pikle['longitude'].astype(float)

# %%
# Suponiendo que df_empresas es tu DataFrame con información de empresas y df_limites_estados es el DataFrame con los límites de los estados

# Definir la función verificar_limite_empresa para que funcione con el DataFrame de empresas
def verificar_limite_empresa(row, df_limites_estados):
    latitud = row['latitude']
    longitud = row['longitude']
    estado_perteneciente = None  # Inicializar el estado_perteneciente como None

    # Iterar sobre cada fila del DataFrame de límites de estados
    for index, state_row in df_limites_estados.iterrows():
        lat_min, lat_max = state_row['lat_min'], state_row['lat_max']
        lon_min, lon_max = state_row['lon_min'], state_row['lon_max']

        # Verificar si las coordenadas están dentro de los límites del estado actual
        dentro_de_limites = (lat_min <= latitud <= lat_max) and (lon_min <= longitud <= lon_max)
        
        # Si las coordenadas están dentro de los límites, obtener el nombre del estado
        if dentro_de_limites:
            estado_perteneciente = state_row['estado']
            break  # Romper el bucle una vez que se encuentra el estado
    
    return estado_perteneciente

# Aplicar la función verificar_limite_empresa a cada fila del DataFrame de empresas
pikle_limpio['Estado_Perteneciente'] = pikle_limpio.apply(verificar_limite_empresa, df_limites_estados=df_limites_estados, axis=1)
# Out:
#                    business_id   latitude   longitude Estado_Perteneciente
# 0       Pns2l4eNsfO8kk83dixA6A  34.426679 -119.711197           California
# 1       mpf3x-BjTdTEA3yCZrAYPw  38.551126  -90.335695             Illinois
# 2       tUFrWirKiKi_TAnsVWINQQ  32.223236 -110.880452              Arizona
# 3       MTSW4McQd7CbVtyjqoe9mw  39.955505  -75.155564           New Jersey
# 4       mWMc6_wTdE0EUBKIGXDVfA  40.338183  -75.471659           New Jersey
# ...                        ...        ...         ...                  ...
# 150341  IUQopTMmYQG-qRtBk-8QnA  53.468419 -113.492054                 None
# 150342  c8GjPIOTGVmIemT7j5_SyQ  36.115118  -86.766925            Tennessee
# 150343  _QAMST-NrQobXduilWEqSw  39.908707  -86.065088              Indiana
# 150344  mtGm22y5c2UHNXDFAjaPNw  38.782351  -89.950558             Illinois
# 150345  jV_XOycEzSlTx-65W906pg  27.771002   -82.39491              Florida
#
# [150346 rows x 4 columns]
# ...

# %%
pikle_limpio.dropna(inplace=True)
# Out:
# C:\Users\jonat\AppData\Local\Temp\ipykernel_7572\2214757940.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pikle_limpio.dropna(inplace=True)

# %%
pikle_limpio
# Out:
#                    business_id   latitude   longitude stars  \
# 0       Pns2l4eNsfO8kk83dixA6A  34.426679 -119.711197   5.0
# 1       mpf3x-BjTdTEA3yCZrAYPw  38.551126  -90.335695   3.0
# 2       tUFrWirKiKi_TAnsVWINQQ  32.223236 -110.880452   3.5
# 3       MTSW4McQd7CbVtyjqoe9mw  39.955505  -75.155564   4.0
# 4       mWMc6_wTdE0EUBKIGXDVfA  40.338183  -75.471659   4.5
# ...                        ...        ...         ...   ...
# 150339  2O2K6SXPWv56amqxCECd4w  39.856185  -75.427725   4.5
# 150342  c8GjPIOTGVmIemT7j5_SyQ  36.115118  -86.766925   4.0
# 150343  _QAMST-NrQobXduilWEqSw  39.908707  -86.065088   3.5
# 150344  mtGm22y5c2UHNXDFAjaPNw  38.782351  -89.950558   4.0
# 150345  jV_XOycEzSlTx-65W906pg  27.771002   -82.39491   4.5
#
#                                                categories Estado_Perteneciente
# 0       Doctors, Traditional Chinese Medicine, Naturop...           California
# 1       Shipping Centers, Local Services, Notaries, Ma...             Illinois
# ...

# %%
pikle_prueba = pd.read_csv(r'datasets\yelp\business.csv.gz')
