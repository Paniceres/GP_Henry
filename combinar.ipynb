# %%
import pandas as pd
import numpy as np
import os
import json
import ijson
import pandas as pd
import pyarrow as pa
import pyarrow.parquet as pq
import gzip
import pickle

# %%
import pandas as pd

datos = pd.read_pickle(r'datasets\Google Maps\metadata-sitios\business.pkl')

# %%
datos = datos.iloc[:, :14].copy()

# %%
datos
# Out:
#                    business_id  \
# 0       Pns2l4eNsfO8kk83dixA6A
# 14      0bPLkL0QhhPO5kt1_EXmNQ
# 28      QdN72BWoyFypdGJhhI5r7g
# 42      lwItZ1Ck3KtpCgG4CPFmpQ
# 56      txyXRytGjwOXvS8s4sc-WA
# ...                        ...
# 150276  Rn3DtOiuJtc3whFySWXs5Q
# 150290  uriD7RFuHhLJeDdKaf0nFA
# 150304  5Z8iBpJMmOMz6G_7oVnzRA
# 150318  VKbQHHUu_cB7M6jQwA3n-w
# 150332  t_SGoRT5yt14OWr64TOulA
#
#                                                   name  \
# 0                             Abby Rappoport, LAC, CMQ
# 14                                Zio's Italian Market
# 28                                             Bar One
# 42                       Stomel Elliot Attorney-At-Law
# 56                                       Smoothie King
# ...                                                ...
# 150276                                Japanese Village
# 150290                                      Pizza Guru
# 150304               SSM Medical Group Dorsett Village
# ...

# %%
metadatos = pd.read_json(r'datasets\Google Maps\metadata-sitios\1.json',lines=True)

# %%
metadatos
# Out:
#                                    name  \
# 0                       Porter Pharmacy
# 1                          City Textile
# 2                          San Soo Dang
# 3                          Nova Fabrics
# 4                      Nobel Textile Co
# ...                                 ...
# 274996                     Maven Realty
# 274997               Stone Castle Fence
# 274998  Health Insurance Solutions Team
# 274999          Bernard Building Center
# 275000    HMR Motor Works and Auto Care
#
#                                                   address  \
# 0       Porter Pharmacy, 129 N Second St, Cochran, GA ...
# 1       City Textile, 3001 E Pico Blvd, Los Angeles, C...
# 2       San Soo Dang, 761 S Vermont Ave, Los Angeles, ...
# 3       Nova Fabrics, 2200 E 11th St, Los Angeles, CA ...
# 4       Nobel Textile Co, 719 E 9th St, Los Angeles, C...
# ...                                                   ...
# 274996  Maven Realty, 2180 McMillan Ave #71672, North ...
# ...

# %%
merged_df = pd.merge(datos, metadatos, on='name', how='inner')

# %%
merged_df
# Out:
#                   business_id                   name  \
# 0      txyXRytGjwOXvS8s4sc-WA          Smoothie King
# 1      txyXRytGjwOXvS8s4sc-WA          Smoothie King
# 2      txyXRytGjwOXvS8s4sc-WA          Smoothie King
# 3      txyXRytGjwOXvS8s4sc-WA          Smoothie King
# 4      txyXRytGjwOXvS8s4sc-WA          Smoothie King
# ...                       ...                    ...
# 64673  u7eyEOUbMu33b5ylaC9dwQ  Einstein Bros. Bagels
# 64674  u7eyEOUbMu33b5ylaC9dwQ  Einstein Bros. Bagels
# 64675  QSRotKruv96AtEv-y0rQsg             Dough Life
# 64676  QSRotKruv96AtEv-y0rQsg             Dough Life
# 64677  f_w3vvy3q-p7DFVRo-EUIg  Black Rock Coffee Bar
#
#                             address_x         city state_x postal_code  \
# 0      1070 E Tucson Marketplace Blvd       Tucson      AB       85713
# 1      1070 E Tucson Marketplace Blvd       Tucson      AB       85713
# 2      1070 E Tucson Marketplace Blvd       Tucson      AB       85713
# ...

# %%
metadatos.loc[metadatos['name'] == 'Smoothie King']
# Out:
#                  name                                            address  \
# 1638    Smoothie King  Smoothie King, 2700 Children's Way, Nashville,...
# 11799   Smoothie King  Smoothie King, 77 H St NW Ste C, Washington, D...
# 28211   Smoothie King  Smoothie King, 2700 Children's Way, Nashville,...
# 38372   Smoothie King  Smoothie King, 77 H St NW Ste C, Washington, D...
# 69852   Smoothie King  Smoothie King, 1010 Beards Hill Rd, Aberdeen, ...
# 74928   Smoothie King  Smoothie King, 6539 E Broad St, Columbus, OH 4...
# 128030  Smoothie King  Smoothie King, 13924 Cantrell Rd Ste F, Little...
# 128272  Smoothie King  Smoothie King, 23411 Aliso Viejo Pkwy ste g, A...
# 150232  Smoothie King  Smoothie King, 1659 State Highway 46W #175, Ne...
# 155218  Smoothie King  Smoothie King, 18602 Kuykendahl Rd, Spring, TX...
# 160925  Smoothie King  Smoothie King, 2760 N Germantown Pkwy, Memphis...
# 195580  Smoothie King  Smoothie King, 207 W Winters St Bldg. 1981, Sc...
# ...

# %%
datos.loc[datos['name'] == 'Smoothie King']
# Out:
#                    business_id           name                         address  \
# 56      txyXRytGjwOXvS8s4sc-WA  Smoothie King  1070 E Tucson Marketplace Blvd
# 9142    GnpvpmHQu3yJ9lrWzd90GQ  Smoothie King        4310 Dearborn Circle 104
# 25410   SrCv57-awxIuy_TT_sZFaA  Smoothie King             180A West Street Rd
# 53662   zrkvXc-pG-loBBGJMN5IiQ  Smoothie King        2701 Airline Drive Ste N
# 76412   65FBKSLEBeHz5Yo_64pMmw  Smoothie King          465A South Kirkwood Rd
# 77112   Wm7fJaAA8WYCk8_QifwVWg  Smoothie King          10334 Roosevelt Blvd N
# 91308   zCX4W7PrPnMVXaDKeAOv4w  Smoothie King             9940 Pendleton Pike
# 103516  le66V6Z0u3Io7VQL-9bCJQ  Smoothie King              3301 Veterans Blvd
#
#                   city state postal_code   latitude   longitude stars  \
# 56              Tucson    AB       85713  32.186794 -110.954765   3.0
# 9142      Mount Laurel    NV       08054   39.96983  -74.903253   3.0
# ...
