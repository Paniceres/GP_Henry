# %%
import pandas as pd

# %%
df_business = pd.read_csv("..\\Yelp\\business.csv")
df_business
# Out:
#                    business_id   latitude   longitude  stars  \
# 0       Pns2l4eNsfO8kk83dixA6A  34.426679 -119.711197    5.0
# 1       mpf3x-BjTdTEA3yCZrAYPw  38.551126  -90.335695    3.0
# 2       tUFrWirKiKi_TAnsVWINQQ  32.223236 -110.880452    3.5
# 3       MTSW4McQd7CbVtyjqoe9mw  39.955505  -75.155564    4.0
# 4       mWMc6_wTdE0EUBKIGXDVfA  40.338183  -75.471659    4.5
# ...                        ...        ...         ...    ...
# 144666  2O2K6SXPWv56amqxCECd4w  39.856185  -75.427725    4.5
# 144667  c8GjPIOTGVmIemT7j5_SyQ  36.115118  -86.766925    4.0
# 144668  _QAMST-NrQobXduilWEqSw  39.908707  -86.065088    3.5
# 144669  mtGm22y5c2UHNXDFAjaPNw  38.782351  -89.950558    4.0
# 144670  jV_XOycEzSlTx-65W906pg  27.771002  -82.394910    4.5
#
#                                                categories Estado_Perteneciente
# 0       Doctors, Traditional Chinese Medicine, Naturop...           California
# ...

# %%
# import numpy as np 
# fila_buscada = df_business.loc[np.logical_and(df_business['latitude'] == 34.018891, df_business['longitude'] == -118.215290)]
# fila_buscada
