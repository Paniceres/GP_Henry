# %% [markdown]
# # Usuarios yelp

# %%
import pandas as pd

# %%
user = pd.read_parquet(r'../extras/Datasets/Yelp/user.parquet')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# d:\Programacion\Proyecto Grupal\GP_Henry\etl-eda\etl_info_user_yelp.ipynb Celda 3 line 1
# ----> <a href='vscode-notebook-cell:/d%3A/Programacion/Proyecto%20Grupal/GP_Henry/etl-eda/etl_info_user_yelp.ipynb#X32sZmlsZQ%3D%3D?line=0'>1</a> user = pd.read_parquet(r'../extras/Datasets/Yelp/user.parquet')
#
# File c:\Python311\Lib\site-packages\pandas\io\parquet.py:509, in read_parquet(path, engine, columns, storage_options, use_nullable_dtypes, dtype_backend, **kwargs)
#     506     use_nullable_dtypes = False
#     507 check_dtype_backend(dtype_backend)
# --> 509 return impl.read(
#     510     path,
#     511     columns=columns,
#     512     storage_options=storage_options,
#     513     use_nullable_dtypes=use_nullable_dtypes,
#     514     dtype_backend=dtype_backend,
#     515     **kwargs,
#     516 )
#
# File c:\Python311\Lib\site-packages\pandas\io\parquet.py:230, in PyArrowImpl.read(self, path, columns, use_nullable_dtypes, dtype_backend, storage_options, **kwargs)
#     226 try:
#     227     pa_table = self.api.parquet.read_table(
#     228         path_or_handle, columns=columns, **kwargs
#     229     )
# --> 230     result = pa_table.to_pandas(**to_pandas_kwargs)
#     232     if manager == "array":
#     233         result = result._as_manager("array", copy=False)
#
# File c:\Python311\Lib\site-packages\pyarrow\array.pxi:867, in pyarrow.lib._PandasConvertible.to_pandas()
#
# File c:\Python311\Lib\site-packages\pyarrow\table.pxi:4085, in pyarrow.lib.Table._to_pandas()
#
# File c:\Python311\Lib\site-packages\pyarrow\pandas_compat.py:772, in table_to_blockmanager(options, table, categories, ignore_metadata, types_mapper)
#     770 _check_data_column_metadata_consistency(all_columns)
#     771 columns = _deserialize_column_index(table, all_columns, column_indexes)
# --> 772 blocks = _table_to_blocks(options, table, categories, ext_columns_dtypes)
#     774 axes = [columns, index]
#     775 return BlockManager(blocks, axes)
#
# File c:\Python311\Lib\site-packages\pyarrow\pandas_compat.py:1120, in _table_to_blocks(options, block_table, categories, extension_columns)
#    1115 def _table_to_blocks(options, block_table, categories, extension_columns):
#    1116     # Part of table_to_blockmanager
#    1117
#    1118     # Convert an arrow table to Block from the internal pandas API
#    1119     columns = block_table.column_names
# -> 1120     result = pa.lib.table_to_blocks(options, block_table, categories,
#    1121                                     list(extension_columns.keys()))
#    1122     return [_reconstruct_block(item, columns, extension_columns)
#    1123             for item in result]
#
# KeyboardInterrupt:

# %%
user.head()
# Out:
#                   user_id    name  review_count        yelping_since  useful  \
# 0  qVc8ODYU5SZjKXVBgXdI7w  Walker           585  2007-01-25 16:47:26    7217
# 1  j14WgRoU_-2ZE1aw1dXrJg  Daniel          4333  2009-01-25 04:35:42   43091
# 2  2WnXYQFK0hXEoTxPtV2zvg   Steph           665  2008-07-25 10:41:00    2086
# 3  SZDeASXq7o05mMNLshsdIA    Gwen           224  2005-11-29 04:38:33     512
# 4  hA5lMy-EnncsH4JoR-hFGQ   Karen            79  2007-01-05 19:40:59      29
#
#    funny   cool                                              elite  \
# 0   1259   5994                                               2007
# 1  13066  27281  2009,2010,2011,2012,2013,2014,2015,2016,2017,2...
# 2   1010   1003                           2009,2010,2011,2012,2013
# 3    330    299                                     2009,2010,2011
# 4     15      7
#
#                                              friends  fans  ...  \
# 0  NSCy54eWehBJyZdG2iE84w, pe42u7DcCH2QmI81NX-8qA...   267  ...
# 1  ueRPE0CX75ePGMqOFVj6IQ, 52oH4DrRvzzl8wh5UXyU0A...  3138  ...
# 2  LuO3Bn4f3rlhyHIaNfTlnA, j9B4XdHUhDfTKVecyWQgyA...    52  ...
# 3  enx1vVPnfdNUdPho6PH_wg, 4wOcvMLtU6a9Lslggq74Vg...    28  ...
# 4  PBK4q9KEEBHhFvSXCUirIw, 3FWPpM7KU1gXeOM_ZbYMbA...     1  ...
#
#    compliment_more  compliment_profile  compliment_cute  compliment_list  \
# 0               65                  55               56               18
# 1              264                 184              157              251
# 2               13                  10               17                3
# 3                4                   1                6                2
# 4                1                   0                0                0
#
#    compliment_note  compliment_plain  compliment_cool  compliment_funny  \
# 0              232               844              467               467
# 1             1847              7054             3131              3131
# 2               66                96              119               119
# 3               12                16               26                26
# 4                1                 1                0                 0
#
#    compliment_writer  compliment_photos
# 0                239                180
# 1               1521               1946
# 2                 35                 18
# 3                 10                  9
# 4                  0                  0
#
# [5 rows x 22 columns]

# %%
user.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2105597 entries, 0 to 2105596
# Data columns (total 22 columns):
#  #   Column              Dtype
# ---  ------              -----
#  0   user_id             object
#  1   name                object
#  2   review_count        int64
#  3   yelping_since       object
#  4   useful              int64
#  5   funny               int64
#  6   cool                int64
#  7   elite               object
#  8   friends             object
#  9   fans                int64
#  10  average_stars       float64
#  11  compliment_hot      int64
#  12  compliment_more     int64
#  13  compliment_profile  int64
#  14  compliment_cute     int64
#  15  compliment_list     int64
#  16  compliment_note     int64
#  17  compliment_plain    int64
#  18  compliment_cool     int64
#  19  compliment_funny    int64
#  20  compliment_writer   int64
#  21  compliment_photos   int64
# dtypes: float64(1), int64(16), object(5)
# memory usage: 353.4+ MB

# %%
user = user.iloc[::,:11]
user.drop(columns = ['funny','cool','elite'],inplace=True)

user.drop_duplicates(inplace=True)

user.rename(columns={'yelping_since': 'creation'}, inplace=True)
user.rename(columns={'average_stars': 'stars'}, inplace=True)

columnas_acomodadas = ['user_id', 'name', 'creation', 'review_count', 'useful', 'fans', 'stars', 'friends']
user = user[columnas_acomodadas]

user
# Out:
#                         user_id     name             creation  review_count  \
# 0        qVc8ODYU5SZjKXVBgXdI7w   Walker  2007-01-25 16:47:26           585
# 1        j14WgRoU_-2ZE1aw1dXrJg   Daniel  2009-01-25 04:35:42          4333
# 2        2WnXYQFK0hXEoTxPtV2zvg    Steph  2008-07-25 10:41:00           665
# 3        SZDeASXq7o05mMNLshsdIA     Gwen  2005-11-29 04:38:33           224
# 4        hA5lMy-EnncsH4JoR-hFGQ    Karen  2007-01-05 19:40:59            79
# ...                         ...      ...                  ...           ...
# 1987892  fB3jbHi3m0L2KgGOxBv6uw  Jerrold  2015-01-06 00:31:31            23
# 1987893  68czcr4BxJyMQ9cJBm6C7Q     Jane  2016-06-14 07:20:52             1
# 1987894  1x3KMskYxOuJCjRz70xOqQ  Shomari  2017-02-04 15:31:58             4
# 1987895  ulfGl4tdbrH05xKzh5lnog  Susanne  2011-01-14 00:29:08             2
# 1987896  wL5jPrLRVCK_Pmo4lM1zpA      Isa  2020-12-19 02:32:39             2
#
#          useful  fans  stars  \
# 0          7217   267   3.91
# 1         43091  3138   3.74
# 2          2086    52   3.32
# 3           512    28   4.27
# 4            29     1   3.54
# ...         ...   ...    ...
# 1987892       7     0   4.92
# 1987893       0     0   5.00
# 1987894       1     0   2.00
# 1987895       0     0   3.00
# 1987896       0     0   5.00
#
#                                                    friends
# 0        NSCy54eWehBJyZdG2iE84w, pe42u7DcCH2QmI81NX-8qA...
# 1        ueRPE0CX75ePGMqOFVj6IQ, 52oH4DrRvzzl8wh5UXyU0A...
# 2        LuO3Bn4f3rlhyHIaNfTlnA, j9B4XdHUhDfTKVecyWQgyA...
# 3        enx1vVPnfdNUdPho6PH_wg, 4wOcvMLtU6a9Lslggq74Vg...
# 4        PBK4q9KEEBHhFvSXCUirIw, 3FWPpM7KU1gXeOM_ZbYMbA...
# ...                                                    ...
# 1987892                                               None
# 1987893                                               None
# 1987894                                               None
# 1987895                                               None
# 1987896                                               None
#
# [1987897 rows x 8 columns]

# %%
revi_yelp = pd.read_parquet(r'..\datasets\processed\yelp\reviews_yelp.parquet.gz')
revi_yelp
# Out:
#                       review_id                 user_id  \
# 0        pUycOfUwM8vqX7KjRRhUEA  59MxRhNVhU9MYndMkz0wtw
# 1        _Ub20uO1MKy4XOVPOdzpqw  lUYboGI6aFbZ0dX27pijpA
# 2        -DjIfoNFAiT5J4kF9hXocQ  SrfDRvGKI8FQq9LCr0dQuQ
# 3        URe-2Zlv7RoY4Ycr9JYVWw  SfMf7DEX7xT82OCcbZFsgQ
# 4        tHP5ihPd_W9OzfkKEWdIwA  aH3AH7V9g60w4pt3LpJ1_Q
# ...                         ...                     ...
# 1138330  HVYhSbKGyj2R39fTDY7sGg  7KBaoiKUhdTvOsRFOMGwZw
# 1138331  CzJMAaOokvASWgVZg8B__w  L-h5y32VWEV60QXuDPW-hg
# 1138332  9_ztYeoSwdz7S9TW8xkDQA  03q-tEfa2aJtKhf00ZZ-hg
# 1138333  jDeNxby0ZI5UMsZzrywedA  NIlmQ38hxTR2w6lNSzJEuQ
# 1138334  rzwxu-a0JjzbGnIimpqBAg  1wx5T2GTopmtdHJZdqvWDQ
#
#                     business_id  sentiment                 date
# 0        gebiRewfieSdtt17PTW6Zg          2  2016-07-25 07:31:06
# 1        gebiRewfieSdtt17PTW6Zg          1  2017-06-28 01:04:59
# 2        gebiRewfieSdtt17PTW6Zg          1  2017-01-14 23:31:35
# 3        gebiRewfieSdtt17PTW6Zg          2  2016-07-14 23:09:38
# 4        gebiRewfieSdtt17PTW6Zg          0  2014-11-30 07:35:54
# ...                         ...        ...                  ...
# 1138330  VnAJnVpXHOIBdg6qFJBc3g          1  2021-08-19 02:30:16
# 1138331  VnAJnVpXHOIBdg6qFJBc3g          1  2021-09-12 05:20:37
# 1138332  VnAJnVpXHOIBdg6qFJBc3g          1  2021-04-25 13:44:37
# 1138333  VnAJnVpXHOIBdg6qFJBc3g          1  2021-10-06 01:52:41
# 1138334  VnAJnVpXHOIBdg6qFJBc3g          0  2021-04-02 13:54:12
#
# [1138335 rows x 5 columns]

# %%
user_id = revi_yelp['user_id'].tolist()

user_id = set(user_id)

user_id
# Out:
# {'tEaM1ztkCR2YvE4zNz_gTA',
#  'APU3fCNTZ0taiUouLAt45A',
#  '0eAr7sbGIbuaMq899EDx_w',
#  'wJnNEUgHxHU7YtW2jHQfKQ',
#  'vH751ma4I5DVMw5-u75YrQ',
#  'XBFdKYJqxZ1lTPo8n3PcDw',
#  '2yJaawM46-mjuFdMPa2MgQ',
#  '1-hmWdLHW6FSerQzkFQ8rg',
#  'B5AukzEgMCpSUyVL5rULKw',
#  'NgskRIPPl7fd8j9hlyEFuQ',
#  'aEwn2-a4sRXSEPtJSGpCJA',
#  '-3TVB_26Dq74-MJETZju_w',
#  'fqaJTlE7PSlpjFhlWUsgsw',
#  'dYeBS_Wz7z7LbzxfKiiIkw',
#  'CAjvATJnt7Ga1bEO6zBuBQ',
#  '0ENzgR4DD5_nLAgCF3fvbA',
#  'P39wggbvsfR7S437B0r0pQ',
#  'BllKtqnA8xVNLW0d4fShPA',
#  'iJiP1oBIeoiQ-A4oftVQNg',
#  '8JWVmrILBRMcjZNdwzyMOg',
#  'bSJxqtv9ZbPdI4_WFIWpeg',
#  'IO6IoCJ6TAYMasx_jfurdg',
#  'zN1tsgDs46Hi2uH5J7KxGw',
#  'N5phGiQjzxANiOcrmw6KTg',
#  'eZG5JBtUusMNS_Ju4XQgSA',
#  'rZsEMa_0LLmFJuMYOL873Q',
#  'jsCWyCFNb1e79lM1hzM5Ag',
#  'AoWbvGAfwE3tKzZr3jFhNg',
#  '4TKg4zZlBJn5NhQEIQPrXA',
#  'XnLfvwqQbVrH43DhX0K2hA',
#  'skSB5mgp0CCRpY6zD-I-8g',
#  'z2p_EKUxcrGSfnkI4l9vog',
#  '1QHRKDWOsCQgV7Cl1gwwfg',
#  'lPbfWQe9uUg4pLlsj2Oqxg',
#  'kWKxS8-7_Cp7l1-uRNLttg',
#  '0b3zUDVjjDbBuG5VWdWjQQ',
#  'bU8UupzhR7SY9m3bA7WdZQ',
#  'mKxxAsVNHFNFmxEMDxHrUQ',
#  '0TzLz8_YukQVXW-I2BqKhA',
#  'k_CY7tPtpmjdd2_BKa3yIg',
#  'ZJsRzpPArkCjwIuKnKJPGQ',
#  'boTB4HavhLOFTaL_1C0DjQ',
#  'x8FWtYnW1NbWWW7XRUTO5Q',
#  'UjZp9OC2d3iyRujXSiKk9g',
#  '89tPVt8hcw8ENVL2epmIvw',
#  'Mabo86VAUohQxmTT3BCKGw',
#  'deFn5e_4K58uXLdaNPbhEw',
#  'Tms569YG1FMxqxUTt1oktQ',
#  'uyaC41wtd6AtfEiuNQ41xQ',
#  'uDwqMOBHZE_tBwZ-m_YL5A',
#  'hg6R0O2V2dN8Q7Oy2a0U5A',
#  'jzB9asJQgdczLc1TZBnxig',
#  'oKkuA6vZokEyJ15baGhdZw',
#  '3wrNb6lS1Me8wIrW47xr5A',
#  'DrmLgn6Tt4fzsQAH609yow',
#  'MPjTaknV4VAbdkpRnTD8mw',
#  '5M0QJ4Do6zkq4EzR9NZNKw',
#  'yK02NJB3DGcsl5U7G3QJKQ',
#  'ozmslzVP6DIIqJFn0Wvx7Q',
#  'iXGBwpXyH8KKaG2Nh6JnVg',
#  'xMZNRobQ69IMM-0knGeCjQ',
#  'Rg1jMM0w3aEHKkl2qmiQpw',
#  '7fW6ZB85lpT-LhObmHBojw',
#  'bE-3HyiBNV7N7hk_YSlZ7A',
#  '_ZK1UKC0zMeVLE2ZVqL-tQ',
#  'TWQDOMSa9w0MFrdM8S62eQ',
#  'COmxVT2GzJoSx1s2Y6kJKQ',
#  'xEs37s7cgHixGa5UQEykFA',
#  'N1sp9wXLotuufQuRANhPGw',
#  'dflZ3RSDEOFTQ7gY0sd7_A',
#  'pBRedE2pGSZQJXHP2F8ojA',
#  'UZnp6hOxqUS2OD1ghmy_JQ',
#  'rzXGWFYvTjUAjFLRO3fZlw',
#  'azxOb7pRjPCKIwBfUEmj0Q',
#  'VThSrVOvHV8l0Ue6gbvtMA',
#  'HdmskDJak2Gj0fB_3oz8vw',
#  'RiM4StqnPPmg20dvGvvr4g',
#  'CPYGFMXl1mOLR5q4HgqWOQ',
#  'EykITJ6hBD3or3zerTFVqw',
#  '6YGvpJllZKPcSnhuILRKeg',
#  'kZJud0lVLNnV-XMDxjAfcg',
#  'bZNfG3brm0ew_zSW47fZjw',
#  'FM-yVgtfZssjIJ2cyVZSZw',
#  'GTft3NNTvie0zrKXR_AblQ',
#  'w02jHp8UzClYDilThMGgJQ',
#  'yEyws3uTorhYUfKB0yIe_w',
#  'B-ZqDoa8i0h6GnIqCD-yTw',
#  '_UQrQquEUW5MjKyCkLOClw',
#  'r7Z1H8Ya4cjrfkEknz7YLQ',
#  'qHOTmSy1fuelCi8Xnp3xtw',
#  '98d-MaXkLXnT9Uanz3t7Bg',
#  'QruEFNrom_4WjiX38lHIvQ',
#  'SZs7akr5VFcnt3X8HI1axA',
#  'r6qZBIxF8reb9n0xPSzkeQ',
#  'c2SrEXSjAy_0a78L5aOH4w',
#  'jrtm6gbELRV6L8bF2qf9YQ',
#  'KFQXN9cj41WNHJFoBwv2rA',
#  'qaCNN1HX9weDhs-LqoXwag',
#  'MUO0B36Chdh7F7gKqoDcBg',
#  'Zxc63pT2eglpVaAR2eetew',
#  '_jG4hcvfu-1ZJFIdTWqqtA',
#  'BU-8DiIshj59fa30U3-Duw',
#  '8MztX4b4T0V-zB88i8_N4Q',
#  'yGyghsHcV4faIm1TR8Z82g',
#  'PkBQlK7fZh_OPy_h0IG44g',
#  '8zIYoxAYqz_iO_0_d9kvkA',
#  'Hs6PdtPc4dWDiRh7yU6UxQ',
#  'nHqDkpazihbL1x1HCIyjIQ',
#  'DKY7WQ9ZlpJdS7vm0ckQ-A',
#  'm7_ksXfD-JqPYv7clTlnMw',
#  'izHq6Vu_9a-BjUpyCaW7fQ',
#  'MsZQkoGimrQ8gEZPDu8X-Q',
#  'ZExlqdie2lcdRPu0MZ5lHA',
#  'Lk6X55z_mZITDXsIbe0rIA',
#  'eZW1jeUTLxbdhhixVaOZ_w',
#  '5utax1tUhaRt8R9pWm65CA',
#  'OkCAq4OExAwEbRsxwNSTEg',
#  'Yc0woEIhYOtsPhjJC2kpmQ',
#  'PbST2NizeySOX09yMCUeJQ',
#  'vKAi6Gh4EN9jZJ09PsD19Q',
#  'ozd__g4pRBPnW0PBAuVN8w',
#  'CrjqLy86RvL_9D-ywRRf6Q',
#  'JjN3v_4ootv92K3rv2_6Iw',
#  'AXX6JJ16gOU8TP4xKQi2Iw',
#  'uwuBvNYfxIMx1aEfHqu--A',
#  'tib7Ar4MNLGFEsP3HvvWyw',
#  '5cnHwkV6N7LOUtuQ1OgrCw',
#  'aU0yW-lm9BWL1a6VX1MBQQ',
#  'B1CvITVmO9aD6NFk0U_Y1A',
#  '7Vqs_Zhzvff-vo0cegk80A',
#  'XPbV3qQWjDNzIGzwoz_zGw',
#  'CyPt8CuriW2RAUE1hbpIWQ',
#  'st9DzLgoOLn6dUggRDBGwg',
#  'lwWaOP_UxaOHHj34U8enPQ',
#  'X_QCpr4nJDMbGy6laD7NHA',
#  'l5FJt9GEZoS-C-n6kk_gKg',
#  'FSe9seizJ_kdL1dE_8ckGg',
#  'SMjUa_JyPjnRGaqkMyKrbg',
#  'n2ZyAo9DHutTjy52hFH-zg',
#  'SzPdVDTxiprF4Nxhjo6kFg',
#  '83eJFhXX_JbHfqWdKTKl2g',
#  'STcvhpU76kNSYjZVNuEVTQ',
#  'OVVXBacZZyLhi5oJtyMFSw',
#  'j9WRXv8KavNF8OZF0KyHdw',
#  '6F4n9EU4lp11jmIIzK7mjg',
#  'I3zSETwKeMRaQuCKlhhY4Q',
#  '0OGkafNGHjbDWQqzsdi8tw',
#  'r9bAyvgWzHLWCizEdln_Sw',
#  'qgE1veIiaVxTzsTX3_vbPQ',
#  'vQLNqGucLX-TkSMvk6RDnA',
#  'AM8T7Gtp8zv7L66m4zywjA',
#  'KlGsdp1mosF1Wppiwd1QNw',
#  'O4XxQ3SPTKzJA96u_H_7hw',
#  'k-llxdV5HwLngQpelp7vNg',
#  '7Mb3OzKxLdSyPSONjNek6w',
#  'bOYmowUsFjWSaXWyFH1ucw',
#  'wpY1VEcQLWUsc-_ESgAhDQ',
#  'YlwFMSBcW18bmqvfcB9s1g',
#  'cebPj4hYvHuyfXkkggrTNQ',
#  'TdLXGb0Ahe32DIQ_gDQWgA',
#  'WyqIuu5NL3ZM5nPsHEcJbw',
#  'cJSvF-aOQjEkKKQFNAA5Ew',
#  'hY8O7CeQ8lpllj2y5ZeE4g',
#  'SzMhrPPzH7_ZZpxh4MM3tQ',
#  'DwUc0fgcqybUuOAaywt2kg',
#  're6phdfYoIcTVXf4q6Sm2w',
#  '5Ehqo9Qxnn3mNWvPeMOVRA',
#  'm2EaIjKneYZYUJpYoSbSWA',
#  'Kq1aNVbTJ_YnmaoldDWyZw',
#  'wOD0pgZpxRioOD8-aBo90g',
#  'e5Utm_IHawHRpPauhntIxQ',
#  'hafVS_Z3paJSiX0GfMhHUQ',
#  'Pf9y1N-_YAWLLPQzNORRcw',
#  'fOCKmOns26MNOxwNkk_nuA',
#  'htgmjwp1syGgqTeHsZD4sQ',
#  'keh52nAddxEDxif-FwVg1g',
#  'DGKMOg4hwG9VzTM-WkgCoA',
#  'j93GB3pZEoQdbJWwSvSy2Q',
#  'Goz8916C5_cQYtP7Mt12QQ',
#  'ajLW6U1QSgx2pUOJbPQGBQ',
#  'lnI0M0Qr4naUyGbGOLOyyQ',
#  'pgrMJpUET-2YIOQp0a5fVw',
#  'VBrqtCJ_R3k94D6IvdgLjA',
#  '6RfI3xIb5oHkMdOufBu6cA',
#  'u4rrWTbuOohgncaDAvoVuQ',
#  'sllk41Me_muB9v91Oqe0-w',
#  'adKB6MRG82wnYQRlTyPaew',
#  'l0Ych8UCxdxwCqK9tu6Khg',
#  'AT66tsv4FLl2Y4_utmlshQ',
#  'fEPuIBzvWq8mIB8Lq6ZwIA',
#  'dg48_1R9QB21NV5DEU93Ow',
#  'sIubzpSg_rIGmz8MLUZqRA',
#  'EppbMPIV6-QeN55_MDgXXg',
#  'KGtrQYE36NbcLrQFGp1BcA',
#  '25xmD-TP-gMrbMXWOndBNw',
#  'fJ4nxgp4FelTR6Ue834N1g',
#  'JAryseT10e5tT4spmjFhrw',
#  'Wp6oUx6np5KBx35z_BqRCA',
#  'gqjArx48HR81q-pFOzpB7w',
#  'r7g3rA6N7Sp3xaiS3SjF5g',
#  '3M85QrvNMsQzQG6e9TJ2Zw',
#  '5n8ctRmTlL2HOapDObYTng',
#  'Q5bL8UrspJIoqeJnWgVdUg',
#  'XIOb2ImdB42LOGczlHkIyA',
#  'z-968UeJw-S8B48vqB42tQ',
#  'UjvmRMgS3AOaYfs7cJqaHw',
#  'KGJvpCi1QKgWAsC3yI9DiQ',
#  '_uTI1VXmoyylrfYfqadZzQ',
#  'hJ5w7llJ7y4T1a1mJ-byRA',
#  'ZL_OsaejKooelmVTGwqaPA',
#  'mp4ozsNrDAWAQ1HjkhlPyA',
#  'NtwJGMLeH3nbTwA9bus5hw',
#  'rxo2Nbe3mcG2rBDvxTuibA',
#  'Fj1OQ2MjXuoFl4YzMVwlhQ',
#  'caD7Fty8VHZe4aWAo-elCQ',
#  'WsT76EL2wZ1wt7__6L7qVg',
#  'yZmdXvbtjdfFrkcKNjuOrA',
#  '42rtnVHQFC7kOBFW58qZ7A',
#  'fbUozkIOj2Vw4qmBbigaew',
#  '9JMJpwRu5dxlafHmepQfMg',
#  'F4qWLbaHfTkrsE2oSWvrcQ',
#  'SQQIWi-M4-vwnkEz3T-rUA',
#  'dS3o-I60kGa9rynK0K985Q',
#  'FXTlcgopE2zH96-fIbqhoQ',
#  'oqQdWrQVozHPa4tinmlc7A',
#  'n974--Zx6Jb9KTT9IR6vMA',
#  '65cKfCFwfJZw72ZLDgxUSw',
#  'LBHFoPH-bgrRenAk4JVDGQ',
#  'xslg9JreGcnV7pCPFrEEyQ',
#  'EDme-VW0ivgMMThQARlM8g',
#  'thpjb-VcVDRAzX3gVwiYpg',
#  'piiz-0d7jq-gUnqUmcdkLw',
#  'mrho2KdaJS06i7AHb6ZDbA',
#  '8UZ8HsUrKuMDWlrYseX89A',
#  'eXoTXcJQfHBpqYEaWExbow',
#  'QEXU4HcSdqkeTPM6BXp1iw',
#  'b1uCYXyUAcmokEHrRnKeog',
#  '2tRVdD0ZclmIh7wY34ANlQ',
#  'FgXqK6ndoXYOZvGvS8xWqw',
#  'ReicFOF-YA8cs6A1DMdIew',
#  '-ul-dOGZXnS23Cw1c09OAg',
#  'p06eLZfXUeMu9zXeibPBfg',
#  'ZLBWZaDQ0yYkNK9dfDYwpg',
#  'Tfvsv48B0onc21aeb-zrXA',
#  '2I_lU4haDNhUl6JIRQKG3A',
#  'JZsUJFDq39XuiuZcf30HuQ',
#  'acZX4az_9eq3DrRjbbeT0w',
#  'vYPuWwDCyHKPyuq7lXoaOA',
#  'bBhqLvVuOZ6s8X3w6mEeFQ',
#  '_MZgpTdm-0HoTl6y9rVHgA',
#  '9U7BXRE7mQh8gtqifLPj9Q',
#  '-A3NxR-D1yIqoTU64xQL1g',
#  'gEwLfhVgjm9nZFckHctBfg',
#  'UUvU_kvlZC6Nk_ZpO44p6g',
#  '7-eCyDACAm39FY0Pu5TaQA',
#  'EiJigOrgJEOuBwpRJsRuXQ',
#  'D0ur1lQFX0jGFwIq9ESveA',
#  'aQpdbu-Y1NYgJhnAJsLa0w',
#  'rlpaN4P8dcNZYuyeKqjRgw',
#  '291pTkWuKZ4Es1O6qx_-sg',
#  'eb7_-iOCf-r0HGFvzZaetg',
#  'yf6VOtfREf-gU7flm855LA',
#  'k3ystGmgCt9rAEPoCiOYlQ',
#  'Jwrmnc5IHrfoDqSnP6VeEg',
#  '2r1l1kxvS4VyiW32LivyEA',
#  '4HuSiPWiMydWMEZnAQ7NSA',
#  'OK8ffyKbLKQKzlN9F1u6kQ',
#  '_aIiqpOznuUeiT28Z2g2Jw',
#  'XHWtf6itzqAKT-nRjJaj7Q',
#  'RPkoJidJF8v2fqhuqUKqGw',
#  'P7v2iybzNhBGb4pw122a4Q',
#  '2t59k5RyvX2sH28q2qg4Jw',
#  'OyUUmxxaPJCLf9pfVuMwQQ',
#  'U7j5mjPQiuCUPopt82d2bw',
#  'cY4aAjCzOkWwMNjry4uYqA',
#  'B9pnLXGirFpHf6tjldh-sg',
#  'KlggaUl50xV4gY4baXNb2Q',
#  '1aoz-DzOWqgPKFZXQIGgng',
#  'JP4EobaofTF_T5Wu0FIY3A',
#  'OvbrRCDdHfs3AZxf1ire5Q',
#  '639Unamr1xpxG7fpst4NnA',
#  'LyudYYcwffZSjGrqtawAWg',
#  'v7GH5Hx1M6ZT9B-6w5I27w',
#  '12GUv17IX7dJbuzeBxBCyg',
#  '1Q65HPcxOFJFP4VOpGOkqA',
#  'r0pt0FPRIIjvFGOhhrc_wA',
#  'dr4ldB3PbG9ZoV_nMDX5jg',
#  'moOzVuFeElk2oBise6RxhA',
#  'M3a2cf0izIOAeJoD_VmpuA',
#  '9umiUnXJaEMhyvbVatLKrw',
#  'xMRFvPQ0pHH2fxu6AzE-tw',
#  '86Ok7MS5IBkHWXSv1NR-HA',
#  '1WE0E1ewe2ZZU0l3V5vNWQ',
#  'yrYIiNHsU9Ql3MpHMJK3QQ',
#  'x6obwGB1QEWU3LujpI1-mQ',
#  'x4NDYZFu3Nuju3u3cgAM_w',
#  '-6MrOJCN-eIe37-LT-uPoQ',
#  'NaQHm0UpWgFhflAEpLfUhg',
#  'P_d8-exV4Sy5F0exMRqGkQ',
#  'chmmLoWG_8kB98Z-EExJwg',
#  'HrYXkua_gc_27f73NuH0ZQ',
#  'y2O20NC2Yy0GqbaYfe4Xww',
#  'A-AVmxYVmyoh-382S98ssg',
#  'yYKFQ0gnBHeK9EnRa5I1eQ',
#  'VYbgV5P7X97jFO6XJQWXWw',
#  'C5TVSdevkU_1Zjct9Kk1OQ',
#  'oKjLZ9bkAMtKQwAIQaqBmg',
#  'ahntdIqEUimNCJXqhEcHmg',
#  'XF5HWkrtZQUmXDW5ghAPOA',
#  'RWXfqP_aSzjRhZHXD_XKjA',
#  'VLbFOUuQ_DGmZT6uKZwa1Q',
#  '55G4n0qVij3gPGRMf0qEzw',
#  'EPIePVI_n065f35GMysZxw',
#  'ZieBJFBvg3E25Ol7NoTACA',
#  '0KI_u3eLhpsKw1vY7Drz-Q',
#  'aCJehFShSNxTu5tzdEMebg',
#  'm7uihqSmKcH5JltA4GwAFA',
#  'ggEFJ7xfncUUSaG-FSCGGw',
#  'FOjWOTVEQyjChNghH-JoFQ',
#  'OuJIogce_EpNjmYxX5zlhg',
#  'VAD2zYZGNfja3S0xp8JpJw',
#  'e3mqAYswDqQKPX7cNAZcdw',
#  'CXglwkLHim9jRyVOqGSUog',
#  'FKCk4oxY35yuEmZ0xY3zRg',
#  'MQbSgJB8S0CSUBdG7Mif6Q',
#  '4d8JAlBFAGC-pwIixqj9cA',
#  'nocEYg21uTHCHkb7p77Jtw',
#  '81vBrCUOhDAkdmLbzP7euw',
#  'uUZUUA0n55Umwk1Ha3p79A',
#  '48ZTznukhLGFnWq39wmxKA',
#  'zoERn0_fx_scePpsGH1NCA',
#  '6t1DWMbJ3bjXl4WNIavbWw',
#  'bom-f8KDyZXhhTPzV9MIZg',
#  'p9BEeIQaq0B_Mm4IQDJptQ',
#  '33M4ZT0FOQYvuB1kyjNvpw',
#  'BlX33fgw6twuoEV8wiuDNA',
#  'Qe-5XKTEasY9eHRbUeKXdg',
#  'rGoDRPS1vTgr3T0QQeFBrg',
#  'TGtnTvl0TYGfSPOWFSq49A',
#  'Xwliz7NUPN-GHA76fsb6GQ',
#  'dqmrbn-KLR4R1_XG_71tsA',
#  '-g5gk3KgRHsPXpNjOZCjKg',
#  'ehvFwk2o3OF8NhtJz_Mixg',
#  'VJRckInUzlHFLjCM_3nmuw',
#  'RpqCKIr-_K8l_r_9qKeN6Q',
#  'I3KILQwwa4aLNfHV8eHZLw',
#  'CnZsXlf-NX2PPkfnmSBTuw',
#  '2U_tEcs98MyzRvSsWKXvqQ',
#  '8mLXf-R5YEr2pLfVrfSd3g',
#  'yOeUBKQyHzTdCaGGK-sAaA',
#  '066u4rxDnRZHXs1caVNbDw',
#  '-Q4CZy6Mo4JjWTuhzhflwA',
#  'uRlJNgkMc-tyeLkHhc_8ng',
#  'tNxAAR4wgrb_92rqzhIfYg',
#  '2RTuZIe_Nop0nyaICxchCA',
#  'cAmku-R1StR23yeYA_1iJw',
#  'geFYFd59nIDUdQRKLCE5uQ',
#  'HydgkxyoFHS0_jh71ZYv0A',
#  '_cOlEX1tgPLbcD0wYa7SsQ',
#  'R2TklBgWlKe0gR_qzfvUvQ',
#  '9U6xKoEmeh-zPGwObaAC-g',
#  'FT7iv2uwEggv-1Va7jhh4Q',
#  'ZypUj4PJnIp5Gi8XOG9uOw',
#  '03UOx7cNKF_O2vol0ujtiw',
#  'fQ4alzKeaoXlkayRV9AtLA',
#  '_GiuTuA102lIzkNUfjgxkA',
#  'ygFXOrNJI6WCzLD4EhJdZg',
#  'Y2H6g-dI60KFkFHbshYacg',
#  'dtuDUTrqa10qmKVajqA9TA',
#  'cUBQOp3_XDBdSHn7EUspkQ',
#  'xBx9P9Vy6Uc4iBsVWpZZZA',
#  'iVPExP4Nv5T4vg7kcsUb9w',
#  'WY4hBziuVu86Ru_0iiUj-g',
#  'Slto5DqBOf1al5x8EXxacw',
#  'WCelN6proFHeq6RduXozCw',
#  'LWr9yin8VD6A23Vq8lQMvQ',
#  'zAO0EB3nFigd9j2JSAJ64Q',
#  'v2b-HQsgTvxxWzn5oxn8tw',
#  'EbnkBj7QdM87XaUrL7tVug',
#  'g865f8P2VsO_ZQUCIq1jIg',
#  'EEoKg0dQVER13iBgc4PFzg',
#  '3Lf2IiNkZUvBvl0xY-y7iw',
#  'L3bx_uMMe4--LIWEVKyT8w',
#  'AuoaQMh0G9eZeuQ-21dcMA',
#  'besukIKVpNHH4cazYyACJQ',
#  'virkjMpSr-XUfuO4_8azAw',
#  'mThsX4DjMBJaXvlzaMCjFA',
#  '0dA4xwp6z2w_8gV_E7nzrw',
#  '9gjyG7uRCgDumPuIf0IlOA',
#  'tGotcvqfUdxPwy72VWAQBQ',
#  'zd2F6XUziy3r_KU8nKDVjA',
#  'qhY0hLKVZ7eITxQt8HGJZQ',
#  'Ib_O5PdBiBa0qN_7Ku54_w',
#  'bdeIrdTLJlsaY1iXkggd-A',
#  'YkgE4dhce9bV2ATH02ynjg',
#  '0XgAcKp-icE3OiUen_ZgZA',
#  'GW2h7M-Ts8T8uI_wl04n6w',
#  'j1yuGmnR_VqAKnRvq75LyQ',
#  '2pBaWnYMZ3-ZelQ4vJW6yg',
#  'Zwgmw5XYI1LukNDkEVLX-g',
#  'z-XzFgMcb9Asq-JEpxqTeg',
#  '1JITyk2XhmWr1No4c108-A',
#  '74AAHrFpotXlZiCeAf_sCw',
#  'O4_C7DIOGVuNfGOVNIxTUw',
#  '4LYalz6j8uMhXbi82a3vPg',
#  'r2QibP2vHpuIhXvqrtWSsQ',
#  'tk9O-CtU5I74zBV9EruTcw',
#  'ihwUjmO_P9o6NJiaZC39BQ',
#  'PcgyHvdduilIJ-O-z_05Sw',
#  'fHlIh3ZtHpQ7qHfwnSMwqg',
#  'nF3OVTV74nlOpvCEMsNw5g',
#  'aPKYYfwrsq5gotibhtXvMw',
#  'fapyYxxCKc4nwfuKr8k18A',
#  'kPohZcOTpJLVjyX6TApLVg',
#  'KD1qbU0fqL0JkPGTLrmxyw',
#  '600GoAVlguBwppZ3Ug0sUQ',
#  'EOFoa8j-dE8BG2bccCQ3kw',
#  'Ag4_d1cRmCq02jUvzqoAJg',
#  'habstCqImrZLrMTFhtbc7w',
#  '6Dst0qryyeBWiqK88YRySg',
#  'css_20RdxGLegAO_pqrBdg',
#  '32AeW43kCrEdT9BhRT564w',
#  'AB9DcX-t6mXs4TnGwav4tw',
#  '3ZhFEYVWnLsX5xUvZCLugA',
#  'uQzU3lxyO8a1JKzYpnm4hA',
#  'XvP6szdNwvx8rUUMu-piKw',
#  'PfaT9C800uXU95NrnBbKZg',
#  'u94qg7osvm2kaPlttn8O6A',
#  'zLSha61vNj16nQYN3kEiBg',
#  'vtPyGF9s-qUavW2MeXLZGA',
#  'VoNQK8km57GOtiyQo5029w',
#  'F0CrNCaDFSSPTD4Jn4WIxA',
#  '1pyANRx39C65K5-uvVCBoA',
#  'NBRz6O5LSwqk3HvQi1QLbw',
#  'gVYFoUcvqmWZjS_KfEWwng',
#  'Psec7uGRLShw0g_xplL7Sg',
#  'f5Lv_Hor71JmBiRHOmZrtA',
#  'UvQCOuaEgdCPrbeDg5Ovxg',
#  'RxQn8d6JKY6w2jOn9wmz5A',
#  'mF8ESdnDN8NsUpxj50ihoQ',
#  '95mTi4_oTrnYgVNghH08Tw',
#  'W7GtrVCYmNaxpfaaJBK50A',
#  'aRnKEG5DnG5rn--mYBjBwQ',
#  'cTV3Voby_t8j-6EHzYkKvg',
#  'wjjTQ9urRGU26_BRY1HPMg',
#  'o_La2v_mhf8_qpQn-JF_xw',
#  'jp-2cba-vL7nLht4C80wKw',
#  'zrJXaPe2Jq06oy6BkDY2Jg',
#  'ZYVMnXnSHrpMAzwIG6F-CA',
#  'rNwUggE1Mar4XbbQ-QvYAA',
#  '5_L_MtqgCgMIhERAWdAgvQ',
#  '5iqJcJzUxqw6xXDuJW8LXg',
#  'Apn3cYcFxj8ZUjemtiRZSQ',
#  'sNYK8_kyxap1klofJnDqHg',
#  '3VOYImSinDyBcDneJhq2vg',
#  'XmmpR_AnymqvG8ZR4LkIyA',
#  'iNRlQfyP9zOF1ng51qqBpQ',
#  '8VXplSyJxWDmwa22qNfgmw',
#  'WO5i5rZknzVPilHHjLMivQ',
#  '2sl1r3xESoQwPF6C0101RQ',
#  '719bVOUTAIHOkFqwFb7piQ',
#  '3ZePQZwQyW9YefjMZcaFXw',
#  'VrOx2X7VCzkifwIsoDHE1g',
#  'TZXC9FP4t_IuYN6X6W-4rA',
#  'kCtxKYjS4Sv_-Pm2mfV1JQ',
#  'rJcEx1-JLcMU4K_2ZUWSjQ',
#  'UlMjxEJUfotpv_ItiFI_pA',
#  'YklQgLF-XFjS_lq2bVX0uw',
#  '51JoI6teXQFIdvW0AX0MZg',
#  'l6JnLmEuBRUVcggvmhqz2g',
#  'Kzpdp2QQca-gn4OxR5tBgw',
#  '8pslbiqWKYLIeIHMMz-ZYg',
#  'rjpYfY0PtV82ZT8gaGjV2g',
#  'HDF99GH_FD2t_Rj6uX5D8Q',
#  'CThr0uuEBOgHLxKwXfTfRw',
#  'Jsl8HuyLdTEhggLNa1OfBQ',
#  'JWMLvXyAJiyY44XbTM90dg',
#  'Qae_RYgGjmbwQTwa2udCoA',
#  '9O4Ds0psIyktWXUUG_QCuQ',
#  'rMcR2yZx7wzZwhae6cJ3nQ',
#  'BnxluM0F_qVgQNCFronxIQ',
#  'Faw39bKks9N42xl6HWHBXg',
#  'kroj3vxRc1kRY8zBedTcOg',
#  '3neW80JFSKESZ6ebPeQD7A',
#  'EIrGYPMIXyXn_PAw7ysxmQ',
#  'LEDuHw0pxyagq36BASSLcA',
#  'DIHWQjfCthv2RryM8lo-Xw',
#  '-ISd3rSTzLHCm24yhHyGNA',
#  '9fHthk8p6IOExsR6V8SDHw',
#  '088SkMN7Hjn2vK2MEUfc3Q',
#  'ZLv3hJ_l8pq9Uf8eGrfUrw',
#  'yHU7X19AEzmUd7HTdGNUQQ',
#  'SmySnC3p75m6uz4wi-zBKA',
#  'XAU8lhC7VeVqQ3oLNrbPvA',
#  'uAMTKdqxgm0YPbxMqLG8Ag',
#  'e9mEMnfiZHpbwiQ8L8n0nw',
#  '4ZvINwiXPhfb9tseP-aM5g',
#  'a6C8NHpAZXqhJQVbiJAqdw',
#  'cLrf1UO_ZkdzAFj3T4Uo4w',
#  'iceLRfV5TdyKPs1Gjpd2sQ',
#  'SV7fGkgUZgyHlwl3vGNnAg',
#  'btM0Up5B7KCV5nfL1HuaNA',
#  'k1OkKmoE618z50KxdjqeTg',
#  'F2Uot2O41uGCcYS470DH7A',
#  'Iujoraiim1LBceWQ1iZ4Pg',
#  'jPUDQ5_KOihpNtOXmu3neA',
#  'UEAhrX_oacB2Az7Mq6vRWg',
#  'a4_fL-E9tmurruFH3su2VA',
#  '-yLy6S3035r3DT4xL7m5zA',
#  'VEQIa3R3u1WK0E_9ttFA2Q',
#  'w-hL_FC7wg0XHgcfHsTGqA',
#  'FBvt6kTT0RUcoIZV5dzNhw',
#  'qX3Nh3lg2KQ5UUO2Mf-4nA',
#  '8358ianA5CeEvvHRPcmghg',
#  'QD9W_18eVlgBvPnIEkciRw',
#  'mqf6mXky7pAkUVy0QCOoLQ',
#  'IT-vaMTmb3dlxDqhjxlrrQ',
#  'MCJ8OPjpm4-eFQmcVnAM0Q',
#  '9f796PqlqzoAqoGngPHjDQ',
#  'KKK-09mSz_qUIRdr-V2bvg',
#  'PzMQqqHC-WEH0csgBMUIdA',
#  'j1IP_bEUEpRLa3ZlEdf2dg',
#  'OoI9gpL8-oUsgHR_cZEdeg',
#  'gNz3n0dPV-IlY1qFNYlClA',
#  'jm9_hsTNhtXK2hEGS8ggbQ',
#  'Ec2TzyYd1yeytMwlvUXVog',
#  'osjSBivCC8L2f98Hyq_DQg',
#  'Pc2D7IqUQvnSqVcrbqCY0w',
#  'rQyRM6TR485aIZJS6IdWHw',
#  'u0dofAj2-dYG-vmz005Jug',
#  'fnDDm3OSYjJ6feldcnV_iA',
#  'GY2oR06OoFo6d38bjzPR5A',
#  '17giOvHwzPIOGesXF9JAQg',
#  'PcZE9rbJOqwAFtgXducvRA',
#  'ru5UG5NQQY0xoB1-hhNCmQ',
#  'XKHpO3iJcoAFZLCJTNwLMw',
#  'Gk5lOeEEpI1jaTNI45ow9g',
#  'RPBIEvkC_btnuR7LlStnxA',
#  'Yimm6c-7a4pgX2pM6ifp7Q',
#  'NbWpoXDdsZ0bwtBw_b-JHQ',
#  'DMa5Hv6msZ3pTDst_JVusQ',
#  'ewgO7C-OjTeS29kw4MOB7A',
#  '0RBgoTQrU8R98U8FYyml-g',
#  'qu9vsQK0v2oX2mePOgV9Rg',
#  '84R955_6WkTliE2bpJL0Iw',
#  '5BUHJfvRBq6PeRXKRglekA',
#  '-3fM7Ktno9kXLzk-WCtBEw',
#  '9fynKSDWnzXecY_UUbGxjg',
#  'KDUs3MrifggBwlyvqTTPcg',
#  'U_2_joUQgGwgr4f-5QPTcA',
#  'gW7DfX0EMg_cKXKnPSHFRA',
#  'rFfBsyHYB1z14nvTvJ_DTA',
#  'FvXh9P6qZW-uLIJNHELKCQ',
#  '5oiQKbv_GCjh5wx8ydJLxA',
#  'ntJJRmSe7_TYdmcycjl5Hg',
#  'G9eDOAPAypPDG0_ytS6AWA',
#  'aq3aNCIybtFNTwW2sUANxw',
#  'Ti2VCB3DkPpiKynexEhlvQ',
#  'Gto86g8Z2Mu8UzccYzuePw',
#  '0w7J4R5OcgOIGHpfl2aeGg',
#  'QjypHRPLHjUeVVQ4dTOmLA',
#  'tw3OSHO2zPY8rvzeV4PkrQ',
#  'QgsdsU7VpnPG-qbvHEceUg',
#  'V94sHU5dfDpzzGlMKJPOWA',
#  '5f2szGtmjoEYycGmm6WK9Q',
#  'SQM1Ovo-_G80yETAQpKKfw',
#  'Z7vqhVnSGuUxzrkiZOSE-A',
#  'TXUekNIfahs1Qg1FGsqXpA',
#  '9jPldnIqTxTe10ef4L12mQ',
#  '32kEdppmZY1e12vJubVvCA',
#  'l3lFOuTzhywo0mnK_IxJZw',
#  'W_vPGvN_V8eoSvaKMvJpAA',
#  '5tzPpCxlbvcKMLqHn27Yrw',
#  'XH_s7iDf5QXOfUYDxwLTyg',
#  'yKg79XEpkvK7sj_6dWIj2w',
#  'rVjoN1wV9ybMM7fj2kbJ_w',
#  'BMRiVcTNgtWd11qtTJ1DkQ',
#  'IdVFxvvVXXibqBWB4G92VQ',
#  'LUqEGuO6heTrY2kzPkuuuw',
#  'dgC36hRE3fnuJHs9z9nFnA',
#  'obWIbV0XQXLQoqYjovj5Ew',
#  '0Rjwm7M5Jh0vwgEycrO7RA',
#  'p8pQGcLM2Dv2e-vKQxnVbA',
#  'pzAtY1az-ydHJGoQZ3DW3Q',
#  'hvXNia3gcRdGM8DUNIQqFA',
#  'lJ1Jpm9iBWCfUEfR4e-2FQ',
#  'oJSqZ7jjUIXEWUrNz5DI4g',
#  '7mH_aX3310Bvcn5Te023dQ',
#  'Gg44bBVLQCAqODQGIia2Yg',
#  'YxEn3uI4ezFUD6u2qiL3Iw',
#  'ZHv2Gdt5HBp638j3UoTtwg',
#  '3QFBP0kx73XJNHhqQxeOZQ',
#  'hcZ-SdnOQG3MwgRuVNR8GA',
#  'uf3A1bIhf-2gsOdMhURjMg',
#  'We1KYjzCIQe1W14abxQwZA',
#  'USAgpUrPgtgyay6YM0NPUg',
#  'N2Y6QX7IBoIN0MtZfOsLJw',
#  'feuq3z1zVQ_az0V-q8Dp4g',
#  'WDsVbkEzTomwpe_op8OniA',
#  'OhhcmZeJ1oGointtlvHDOg',
#  '9Fpcreomr5kkN_zoBWLv2w',
#  'iShhchgwk4Z7Yw2Iut1_PA',
#  'r63WWyOBJuKxL0JX0Puk8A',
#  'oHamE55h6Fr5b27dON9Law',
#  'T4zHCow4oZAmp2xlrr8m2w',
#  'Sro1K9j_rD6MEfpZRBe0fA',
#  'P5wuiXTT5EVYqrj_-1KoEg',
#  'PGx_pmKGlmzK4Y_15IWAUw',
#  '4EAkqxueQ1OU6JbklQtGBQ',
#  'XTRA99BdEB5NUwkp2p-t4w',
#  'BJTxWby6flPflYc75eTemg',
#  'xWMEagY4pExMhxE3mcx-bA',
#  'cpni23435aW6gqh01Nkysg',
#  'wZyxRxXaPHKAkrrW-mNpXQ',
#  'ftgIveX0azf3wJXGzKwlgA',
#  'DAsJg80ZX8gvNtylv6drhg',
#  '0kjVY6a1rfKY5eEc-CBaBA',
#  'vFV3V0yTv9GkliNnmCHEwg',
#  'XcO8cMb5fa5g1KgjN1Mf0Q',
#  'Z0LLOs9zbDYZMOyZesqpUw',
#  'WmAN8_slUKc97d_WFHeMkw',
#  'JYxVDzxCdomASSfmOb1nJQ',
#  'r7Gqqze9Kg7TVusdCiUrcg',
#  'HKwRK0V3dlSe3ZrSHGGYTw',
#  'RH_GggLBTwfpJubkM1817A',
#  'UON41O5Lh4QutxdSVoB_JA',
#  'pfbDg4Y1cbibroVrY_jodw',
#  'miisZN8RCn5IlUXDfpWgTQ',
#  'ntkBOLzY9MTHQNcwheheAQ',
#  '53d4qjoAw3XVlFbpfRS5TQ',
#  '0kf7dRseVd1D8k1ccHmWew',
#  'vZ6Z6bDI_JQGBJ7-r40zmA',
#  'RnKKbK1TfpKdQZttV-_J0g',
#  'QU3UxTVeM0Exz7VV0yl8Ow',
#  'KwYOF897y6xkSWea40HTWQ',
#  'IoGFfgpCWUT161l5fNo0hQ',
#  'iMZhhhMACQE9ehSYiae5mQ',
#  'cy0xS4zj0zOOJlTGLVuTTg',
#  'F3LyXZfRkMV50teIx7QpJA',
#  'j7MNlIwRPjdgRhhAsmgFbQ',
#  'ljstIHjeJcdZHDZ_-unhgw',
#  'MquXb8TAGonzhiteThH12Q',
#  'gRa8Qt2fkCwAbmkvX9RL2Q',
#  'MhHtPfvJXweF4xwK7Hm5yA',
#  'uCNgCZCuo07ew0sWPB1z7g',
#  'ds7cyaMK6J4rW-69me4hYA',
#  'kDuS3rhj73VPsWsHxFlvSA',
#  'xLjaM6XjzdBLkBUjORkQCA',
#  'IhnCbJE6v6mi39Da3jxMsw',
#  'azwezZ9crt63brWcAd0mxw',
#  'i8vWvLPdXbwNunOBnoOgww',
#  '1eqQzR6PJlYQVN_rbxZZ4g',
#  'D5YDJdpTj5TTk_oFL2YVkg',
#  'vbuoU-fqA4VaP4TqLR9SgA',
#  'Gi7Sb9E8ZZSEDS5dkVhMoQ',
#  'td0dFAX_aVHyrGIAIyiXpg',
#  'XOGRqvC3_ZZ2t0cTlJgVog',
#  'QvxzC4V1UV4Y8udGHDFvug',
#  'SEBHFvDjfnKpjqBqMLlcIw',
#  'RUOWCSWos2ujg-Rk9-w9Ig',
#  'chIP3qXC-J8No3oZVcEYng',
#  'mgoiAY-KyUZLRmxMSiQttA',
#  'zRwoV6U1h0YgiVKKYWCGdA',
#  'csqqinvOIk9CLI6yDsnTPw',
#  'cntX4-4bzWY0egddeLdQhw',
#  'udVMf6FFAvp3YQ-ODrRIvg',
#  'reOpweVNLua_2uXt6OPtMQ',
#  'OC_WdUmY2fK-c1SD4JqSsw',
#  't_Mbrqmv92_ygXWyaZb2vw',
#  'FxZ4ph3iNS5R8mhnk1jpkQ',
#  'kVfSNmWw2ptpA9Kyoac_mQ',
#  's8R9mAk2yeIhZOdCEd5cPA',
#  'P3AptUDreP3kk6ID4z2E3w',
#  'xk1RiIiU_D0MVu2U6KFOqw',
#  'eQdVuvkpYF2VDAkN_aeYlw',
#  '01q5qz_Q3ASyu553pn5ojg',
#  'jQZg8PLG-TibRpKFyTH1iQ',
#  'eTl0exjmmiVXUqLuR8EhKA',
#  '0mYNAVDIzW4fzgAQ5opGWg',
#  'bqZ4gpGRgZHRfaqII1w04g',
#  'OzBn1twQ-YYeYO1ySh1_zg',
#  'o6QFmZL3-9wdxRrP2oCw6Q',
#  'fkEV217jztlhUix0i2pIJQ',
#  'HfQ5CMjXYJWhrSRwz8BLqQ',
#  'U6dVypW8d4LjzglrJOhc-g',
#  '9pYgzWpCG-7QipqfOJl7UA',
#  'ba-cX0j6jkRL7bEU_1OhUw',
#  '8UPCsWJG0XsM0pyDZgV34w',
#  'WIb7Ny_kQgh9hTj_UQWqow',
#  'Vw7XQv64N4j5fWSG4IWpHg',
#  'CXOsBSRyhCCD43f5JryUPA',
#  'A9G2Udz7B0rMjwf3MLEQyw',
#  'wpzlt0Tn3_rixPHvalS_fw',
#  'q8WUCCqCpNnt8_YsqfOaQA',
#  'KM7VfmwTgszaX49sbBCWVw',
#  'McT2QjDN_RLLuzAeBx2PiQ',
#  'NScGPV171uLXhy7cMOPv0w',
#  'a5zS7HpBwAEoRUyGR_G_kA',
#  'wqnvRT0p0qMYz465WTxHzw',
#  'WfAOwrsqVdqCn7KA8aQfSQ',
#  'JWcLMYG4O-9_J4WQvLUwJQ',
#  'PlhwEas_V53mMha3f_qJ0w',
#  '9sFm8hp5paha2zUZKjucUg',
#  '7-SD929PphKzjggeJIJlNQ',
#  'E0X3JRKTDc3jqFf7oU_MwA',
#  'Nvp6C1M0RtKpk0w-9Vdd5A',
#  'zlI6r37yHE6oOsBXykAwxg',
#  'Q18A2wVKV6BBGxuhe7CTKw',
#  'TD0Ofr9YZbWXdaGCsPGTzg',
#  'z2-KhBFi7LzqtczVmeP0iA',
#  'EI9nJ-KdFjdbVGjvqNr2Hw',
#  '1te5h4tPTEekZbo9BmrwLg',
#  'CBdoOu8zBYSx8Q2pV8J_wQ',
#  'cr0h_wdeAirPONY5E28kXg',
#  'RfBImeV9uNWNuKGnyqikxA',
#  '0QZLEVwDwmfMt9ScUgOpCQ',
#  'TT9ekCSBCZwGvQITdlH3jQ',
#  '4KOkdd3_HkCs45ZNWSJ0bg',
#  'AGxsV2tFsNqeKfApRWQE1w',
#  'OThBJXbPCJ3hQTCInnpbrg',
#  '29Lk7XLQ9YTLkcTxVuXZrw',
#  'ae_Nszq28O7Tb6HCWpkJ5g',
#  '6NS0Lbsx63ES5xrMMVtmsA',
#  'KEDLI2GtiNQ77V4f5JjtOQ',
#  'eVKIguHZxu5o2oUR7rUMvA',
#  'XmqH7TmcahUvGHd06WZiIg',
#  '1j9gT-wbnRjCEcDNmJGXOQ',
#  'J_vtUWNWPgAPIQVeM7TkqQ',
#  'fRmeh3pcOWr0imB8Thbt8g',
#  'EADSUacYPJ_cylN3CBC3HQ',
#  '1p74yg1t_uoaFofJ-LVbOw',
#  'QG35pnGY-k9NaFYHEn_HGQ',
#  '5fDYBzmZ9kXuFTYGRXIUtg',
#  'x7Yu_yqZl3YUQ_sZvfSP-A',
#  'p57G0vZn7Paug23NylgXFw',
#  'dUM0kAoKoBQkhZqUo-VGDQ',
#  'Bt2_Lo2Il7Lz9_WVZqyB-w',
#  'CQnIa1IefJFXXayNl_Gi-Q',
#  'WdhObbfGC-2RtGLgRr_YJQ',
#  '7AZ4Iq5-XsfbtiPC2k-J5Q',
#  'zn49uoRL-KTsuvzdn47iCA',
#  'XM3uvOBmsXjuZfOt8xfUiA',
#  'p7hMUUe-NzjGmQfZ2XMA_w',
#  'hzqjOliGFSWcdWrEgcncSQ',
#  'qFnMkkgvLU7LaVorCbvd9A',
#  'jeHHY9PvpGhZEdI2skr4vg',
#  'Zu0XNq8YnVBNFfRXuv727A',
#  'vbE-UHYd439gJbKAUW6B8w',
#  'FX4e43-DqqWGSEKb7UWMVQ',
#  'CmjQyDQImnlhXROkVOrhPw',
#  'INxS8qx3HAPBpHt_wlUP9w',
#  'cmBt9taGLO8-wG4E53aL8A',
#  '9SgFzWGHp82gjF16A7hJkQ',
#  'lT0ufUQYdE5LEExqgfb2mA',
#  'iYSpKBdY0CBVWJQwDzBjJQ',
#  'f0nTbNxwtSTX3JbcgMf1HA',
#  '_n7yfQTbGbdnZjxik__qLg',
#  '7ZeGcXKm37A3kavSaRFofA',
#  'S3ljeCrpEQ4AK6ev1m6ofg',
#  '6JiH-OemNcdf42TsXxG-XQ',
#  'Nr29X49dgXs_tB36E2ApUg',
#  'hxoqvyJZupLlV1dfhCTduQ',
#  'woaqroOCDw-jMbdmJ6xn2A',
#  'jIqpfsQH652z9vGFmuSPUQ',
#  'YHm-whlbWBZ9QtFJR-VyNg',
#  'y3EsnLjo8PH-ah7SzfwbVA',
#  'i7A72UOfldPmS4vMmEZmeg',
#  'RWD68yTs5DZ0f0l4IhWnrA',
#  'Cokv5F_ZGjsVmlF9IVGB9g',
#  '4r0o8tUMYChLOznCwf5ltA',
#  'Ih_UHA6m69pAm5EbjLkdeQ',
#  'niWQu6QFI0Orw2SG32m0kQ',
#  'I9awdj1_Vtv_8ud6f8GRgw',
#  'd-6mO6SgRpHEN1J63RRwew',
#  'oWa3zT1Vrjmgq2T-0AE5SQ',
#  'heBqw93t8X3mnxjffyJSAw',
#  'W9BQX_MVwP1-mvNiA5kEqw',
#  'FY5LJOG8mFnOQnbVbBXj4w',
#  'ys26Cac6wDZr5cIzMRCa0A',
#  '9gurTp-5qaWQBOBw2lwYBQ',
#  'exVi9sniZb9ExL8Kd7THaw',
#  'IdrgrErOHl-vnCpxpmjkcg',
#  'YgxIhK-pKNDze74-h65zCA',
#  'a36F_h_VIVFWhhLyxqS0_Q',
#  '2A0eNNGR2Ad2oppZb0vj-Q',
#  'VxPaA69aRSjzV4HMbps4nw',
#  'I3hCuD1sUKKfQMhfnnvsNg',
#  'Neq-EGhmFG1UoIhnLvoCTw',
#  '32q8ANt2SETx-u_1PlPSAw',
#  'GVx81_2MDvYb0-gEYTLvtA',
#  'oKFeMhq1QDXtnSexBMczSA',
#  'Mfq5gZRSEhryx-1r5FP3ig',
#  'D8p0OhFBXJSyNbH-mqGYhg',
#  'uBNsoC84-WPfaunlUJm1Qw',
#  'IkJ37GTW5WsDw4MhMC-pTg',
#  '2ll7t7MSpUoyLTIQz8-KuQ',
#  'UlON03I_fCVPGnO89RO_FQ',
#  'WtHiLVxW3GnxMUhvz-6XcQ',
#  'P93oh7ZxFsvewn0nGnmAZA',
#  'pOaaxK_uxcD4UximmH1V1Q',
#  'zxg6jOgJawMTX7e_lBXI-g',
#  '1RrqCh40R033JdSP68AXmw',
#  'ZPGTXx1ZKZT4KwegkfwNyg',
#  'iFxfoKkYmMdIUqKySg6xQQ',
#  'xL02uHqMadSxTyflcUVgUQ',
#  'Ib_xqcMf_1Lt8bOcwJp7gw',
#  'QoXD-IbfEGVx7OvB29um1A',
#  'qlYM_ZW1e0PE1Jc8O3k8Og',
#  '4ptU-WWGimlMn-PQ9sp0Ig',
#  'dqGjVpcBu7ZU3IesAy66iQ',
#  'GL6FxWO3qYu95DNf_fW2lA',
#  '90X5q7EiJ1eRDXky4i57eA',
#  'bIIuCxt0va5bqMdfQK3ZBA',
#  'Sz1E8sxv7bmNFhiti1eGuA',
#  'SiFuR_h7dOV8O2eS4uCs9A',
#  '3Ggwnyqmw5rmsKr2Kumv3g',
#  'SCqgGKMJrZPY4o7D0NJRLA',
#  'jf52ONMBRKlTcUc5MsDctw',
#  'SkGPiLwmdnHDglBnicAxwA',
#  'qbrw7vlR0Q_7qPoVg5cgJg',
#  'ukPsBKCRrmikaMYrZwKIIQ',
#  'O4FhaATabTNsN-p4qEWyZw',
#  'yktQ4XLlW0xfTiychJv0Eg',
#  'BlkkHyrislFq3bGAsUMZoA',
#  'JdH9N9Y2u1IesmBFW2lppw',
#  '2mtngw8j7t_V2g4l0w1BJA',
#  'hMd-eOZzzC4WDq_zKcBobg',
#  'eQR2hHlUdYls8Gne6DlX8A',
#  'yx3Nf3LpRX20v6dfr4TH7w',
#  '_7l9EV-nIo05DP7_vH_jEA',
#  'mz69IdSnUcwtLDDgwlRRyg',
#  '_GdoRFc9GNYPb25RArnVTQ',
#  'icNtBTwmZMoNTAQAYUZ05w',
#  '1FewsdvGodYhLAuVfHTY1w',
#  'HuPiNdVA8aIUIKXcn_HxoQ',
#  'AFHSZBfSjoMvXtr85EqCMQ',
#  'ixFcdkFwvDda1Zi4AW076g',
#  'CACT_ltPpVLNhvVDub-fxw',
#  'Ya44uDYpCkeuinaxTLV-uQ',
#  'ag26yVYu4Htyer4Qy5CExQ',
#  'fGabSNyIxlVhVw_wlacVhA',
#  'lwUPbWUpGGTdSLBeC3E0dA',
#  '-3vF159SO_SObNPKMy8Y5Q',
#  'pz64Rqb9hxGZ1Iv91d33ig',
#  'x664D89uz98b5PQwBWty-A',
#  'JM2Z75pRvEKDGFRMxpqKuA',
#  'i6NPkuSMxFncSE-FrXa8qg',
#  'JlCP4JLZyo0R6UJ7hFDtiw',
#  'xD3izx1WyzWWbL8wPdZN5g',
#  '21hE-5zICY6CAvCIc0tXRQ',
#  'G4g815KbVfI6UGt8NU351w',
#  'aAMMummMTR5Guwj9hVl0Tw',
#  '3sYIdvDLlHa1SYdYXV_wBg',
#  'R-R4EncdzmNhrUpprn5qRA',
#  'BAJKnLxpT4n4kEX4jFUvvQ',
#  'Rc_peS0ML1iHODp_M7U-eQ',
#  'SqeVeNkIl9RgODVMQSuTKw',
#  'DAcBVjMJ5LmAtYvsfPRquQ',
#  'JklIwkQoTZZk8EsbFdWkiA',
#  '0tPfokOk6ecvTm2dLTZ6LA',
#  'iZLbB6qpNcDPm68X9ZTNdQ',
#  '8ocorqcjFoHawf2n8ywK7w',
#  '5EHAUUlOgKehfHgPHNFbNA',
#  'bgDIUILZ0vhapB13BB2jOg',
#  'hZGw129u7AnsPnyIHxUcaQ',
#  'WhwqroXXiFNJ4cKdqHqY7g',
#  'ca_L-Xsh4IeCmWztpph76A',
#  'ZmOD-CL2iYck51Yh3v08rg',
#  'SoekOk8YxlZd8M1cbBXcFg',
#  'EF5jrjPgyDTLOryGO3n-EQ',
#  'FeP08qobd8iVTuXi9qHv_Q',
#  '8wDDyQc7d8Nk-SLpZWXGgQ',
#  'aD2AYrLa64t_rFnCaVVysg',
#  'Qk1BkBOZ1rnkQwExbhtrsQ',
#  'sT-8izHZLW69hfgk8kyUXQ',
#  'mfFJnHun-tCn86lou7Uozw',
#  'N4Xi445crrIb5SJrR1uyVQ',
#  'NQBvkfrwRZKZug328jJ06Q',
#  '4jYjVVz4JZ9-trJkQOrMCQ',
#  '3arhTzemPEVNr4OAfm-b-g',
#  'pXaczB_4WMucxAoaxVvLcA',
#  '1bNGQsi5HEksr9y95Q9YEg',
#  'lAPc5Bi-uboOSHPEKeRx7w',
#  'rJENpOLR9DVFB1nHdwif4g',
#  'KK0aefhaQIuT9zr80A67_g',
#  'S9uau0NKA3OeG_FOxUfBZw',
#  'v-gfpXHE4C0wvQzy35umOw',
#  'x3WRr5tbIgd5GHT3l-hyXA',
#  '3dIuWvEdByvZ8dH4VWjbxg',
#  'xsGzNrgevS7SZps--J2WsQ',
#  'WSAWt6USRwofsHTPUsYeoQ',
#  'WCs6D3egNYrGIpOjhULBOA',
#  'NvCxOrUmrks7G9Dysrj8TA',
#  'rFHmveeeTazN6sMyhGRLTw',
#  'HSqsZmha201dm1Fj-YhERQ',
#  'lIMOG1hQH_OaQ8TScTn4HA',
#  'xtmZmlA4ye_cys5PgVIrAQ',
#  'LP9gf5QfZX3XhmUPqIcLGA',
#  'eDN-m8v0NIpqQoUTc861vw',
#  'ExmpPy3-U3w-YTE9VcHOHw',
#  '9PaBynqghjQ5eEy8Hrbxng',
#  '6s9RGCm3mLa6IeL6gwWMpA',
#  'gyaPLkyg648h6wdQ0Ykfwg',
#  'N88XN-rGmw8MDwug6s_SQg',
#  'qHfdnKq2ssRqTeH9fN_AHg',
#  'TX-qncm8o404xYecBVOc_w',
#  'EfL5cSqrnjMVct3UZR2Esw',
#  'eFcGWPzoPozKauyIcCJ-vw',
#  'yAIwM1CMdUc1mxka-KFsew',
#  'cfaxpMrv_aM5t5BOQ2yxyA',
#  'iMGNvQsnq-u8ydyUuAwFwQ',
#  'WsPzD9onaYAzkwcpAWdOCg',
#  'vihNt7s-fUC7vIxanVf5Hw',
#  'RjLpjgxpT6ADGLtk0nrOkg',
#  'cBK8oUS4gh8F8WwFtt5kTw',
#  'A3Hn7DI4_YMdtMqHlljucA',
#  'X9Gc5pm6b3O1qC98rQKA3g',
#  'UydHEH_dmwVcPeU1jVSf2Q',
#  'sIlYtVKVIqBOexwSiKQ-iQ',
#  'a7CMLS6jandIYTGwiZE8sw',
#  'w4dX7IE6uqAr6dpJ5oj3bA',
#  'lL4xBbXPb9NoIsxqw2eGVA',
#  'wuIMhchhz_sU1wWPzrsZDQ',
#  'M838RkCNOSgDXliw-g5WpA',
#  'wz8gmIkryCqwgU3yx1lFKA',
#  'AMJA6za9FIwAsRSzFiZH0Q',
#  'yrCP0N_tODffJUjsZkyT3Q',
#  'SIzE_HOKQYKhwhdj6Jm22g',
#  'mb-Z0J8K50UbflbDcrAU4A',
#  'a7UZQ-jLHoSJdZbjcj7yAw',
#  'gpwQ8S7EVbxWGTYSJQg1ZA',
#  'urhD6C9gmqpPxpJxhoPqig',
#  'ltK5GlkQN6_8k5LBxgbe7A',
#  'CsO3vh_O8-YH_br3Q0DJiA',
#  'LOaGAWjtkAixJYJG5ltyNA',
#  'jNEJjYg0egXCLKC9SLBtqg',
#  'RvTgTNI_zIFx1q8N0kpJNw',
#  '76rib_fMPdFP1I27ZsFiTw',
#  'eROFe4QhMJUECuJeMn2xUQ',
#  'GyNKRssbW1KeN67abfUFZQ',
#  'tmTTS9nS-Nj9F_VCwf8puQ',
#  '6pM8xuIoSiMkCkY8vtKP2w',
#  'eD7XG2ceKseLMB1FmAammg',
#  'ZA0YDMN3aVSzp4CaO_C7wg',
#  'XBAQcr5y6-AErLmaJWyshA',
#  'igaj6wC3LG2AbQjJx_Pkkg',
#  'wd6n9OiHJ7Rhrv4VgHbUaQ',
#  'ZNZuk19DvSWsgz_PBEbr6g',
#  '99XV21hXtIK0N3ajNGo_Yg',
#  'ONfaebhJciMKiBXETw0dbw',
#  '9x_Ch7ses3vdCk7wl2YB0g',
#  'KZQgjISwZNQa2gDZcCE4Gg',
#  'WMWc4GELAvcTxcEZKrUDJw',
#  'J3N2Zx1edv5jfPs_x3MJDw',
#  'j84sng6u1a60lNPBGaWZRA',
#  'hMSZ4NFuGRTVbYKHw0KT-A',
#  '8NCgGiafcU7z9rCFlxjYfw',
#  'iJNBNx_TIMKDkfCtReZ2vA',
#  '4PbQT_9yUl6YoK35derAOA',
#  'S_WEyzSmLO9oN_8Xb_ADtA',
#  '3LQEk1RasAuZdiRmT4jbCQ',
#  'oxVafgKLWBbwp1u5NekUmw',
#  'iaDjcJVOWvueUhLAqIYjHA',
#  'DOxYJf169LQMucQgyG-gNQ',
#  '2sLnDObA0Q3Y0qWbpAzFUg',
#  'xb9-sVUs7gDjDrnRNPSyag',
#  'JL4VL9kcJugRVg750Ptukg',
#  'kDi2Z61m92fWrOY9tIyiMg',
#  'rC9Mj8ZwQRt9x0zifw5g0A',
#  'e77Wd23EiccXIWndqS2lhA',
#  '8DbtMYebRYGqVUbHXq-s0Q',
#  'jVesdzRBrZsvWd_oiE0c4Q',
#  '33C_tPS9BcRaV_w335NebA',
#  'Wj9lefRsE4I3ufVYtWef0w',
#  'cngeCeaOA_diSpNJu457HA',
#  'pgdaLlOZ2TK2zSK5-5WdzQ',
#  'McTp3HzC4zmUnhyK6YPB4A',
#  '8l5noZpcaOjyMn4PwFcjOQ',
#  'qaeaYwpFwIyWz3wxkDGGig',
#  '_n6HuoOlY2Vumz0mdfQ5PA',
#  'ianrkXmM-1nqMqraD0qOPA',
#  'Wb4O-xPL1iaPgt9fnQUnsg',
#  'Jx6EHw5xr3y6uGDndI801A',
#  '8sqhuF15kAvsXl_5BULvCw',
#  'v_FYTOEqaeJQBAS1oDchGw',
#  'NaWSRaSwF8moJVT19tlZbg',
#  'FbxsV42a-7VymViATg2lMQ',
#  '2HWADiBV3et6C_t8xkUXZg',
#  'pU79yK1LGIEMVqw9XNPivg',
#  'I_Ykuxg4oWH678r1s3xssg',
#  'fl_7JrPNuEoan6-HroWdzA',
#  'MaHI6TgZEh_f8lSfJlZeoA',
#  'QDvTFVWHDvnyRtZ53AkLfQ',
#  'elfFrQ2O0RJlZBHYyIcn7Q',
#  'MlpGoD6tlJABYk1L9O222Q',
#  'yHyE4pb_L8x8H7gsm_BySg',
#  'hT36szHjK2dSwAHprkSjmg',
#  '6EpORH-AM9GbmvbhIyEeLQ',
#  'dZw477Eia2j6mENV8WVqZA',
#  'JaT9pTWJWLlM9WWZ06UPiQ',
#  ...}

# %%
user = user[user['user_id'].isin(user_id)]
user.reset_index(drop=True, inplace=True)

# %%
user.head()
# Out:
#                   user_id    name             creation  review_count  useful  \
# 0  qVc8ODYU5SZjKXVBgXdI7w  Walker  2007-01-25 16:47:26           585    7217
# 1  SZDeASXq7o05mMNLshsdIA    Gwen  2005-11-29 04:38:33           224     512
# 2  q_QQ5kBBwlCcbL1s4NVK3g    Jane  2005-03-14 20:26:35          1221   14953
# 3  E9kcWJdJUHuTKfQurPljwA    Mike  2008-12-11 22:11:56           358     399
# 4  1McG5Rn_UDkmlkZOrsdptg  Teresa  2009-05-26 16:11:11             7      18
#
#    fans  stars                                            friends
# 0   267   3.91  NSCy54eWehBJyZdG2iE84w, pe42u7DcCH2QmI81NX-8qA...
# 1    28   4.27  enx1vVPnfdNUdPho6PH_wg, 4wOcvMLtU6a9Lslggq74Vg...
# 2  1357   3.85  xBDpTUbai0DXrvxCe3X16Q, 7GPNBO496aecrjJfW6UWtg...
# 3    23   3.73  y2GyxJF5VQWohxgw_GR7Jw, 0NRn4eY3JWN0IFqvOSa5gA...
# 4     1   4.29  piejMEdRkGB7-1aL4lL5NQ, X0zFOU6iG95-feQKOXkgrA...

# %%
user['creation'] = pd.to_datetime(user['creation'])

# %%
user.to_parquet(r'..\datasets\processed\yelp\info_user_yelp.parquet.gz', compression='gzip')

# %% [markdown]
# # Usuarios Google

# %%
googleUsers = pd.read_parquet('../datasets/processed/google/reviews_google.parquet.gz')

# %%
usuarios = googleUsers['user_id'].unique()

# %%
usuariosG = googleUsers.drop(columns=['gmap_id', 'resp_time', 'state', 'sentiment_textblob_resp', 'sentiment'])

# %%
usuariosG[['user_id','name']].drop_duplicates()
# Out:
#               user_id             name
# 0        1.089912e+20          Song Ro
# 1        1.112903e+20      Rafa Robles
# 2        1.126404e+20        David Han
# 3        1.174403e+20      Anthony Kim
# 4        1.005808e+20    Mario Marzouk
# ...               ...              ...
# 9599884  1.167003e+20   Alpha Imperial
# 9599887  1.077358e+20  Mary Judd Nunez
# 9599889  1.104871e+20      malu norada
# 9599932  1.166060e+20  Gregory Jimenez
# 9599933  1.032183e+20       Ikram Khan
#
# [1371954 rows x 2 columns]

# %%
usuariosG['time'] = usuariosG['time'].astype(str)
usuariosG['time'] = usuariosG['time'].apply(lambda x: x.split('.')[0])
usuariosG['time'] = pd.to_datetime(usuariosG['time'])
usuariosG
# Out:
#               user_id             name                time  year
# 0        1.089912e+20          Song Ro 2021-01-06 05:12:07  2021
# 1        1.112903e+20      Rafa Robles 2021-02-09 05:47:28  2021
# 2        1.126404e+20        David Han 2020-03-08 05:04:42  2020
# 3        1.174403e+20      Anthony Kim 2019-03-07 05:56:56  2019
# 4        1.005808e+20    Mario Marzouk 2017-05-16 05:01:41  2017
# ...               ...              ...                 ...   ...
# 9599941  1.091054e+20      Rydell Rene 2016-09-01 01:03:33  2016
# 9599942  1.159805e+20     Erik Johnson 2017-07-26 19:09:52  2017
# 9599943  1.159471e+20      Angad Johar 2015-11-16 17:06:38  2015
# 9599944  1.179236e+20          Pedro C 2016-10-06 10:41:33  2016
# 9599945  1.170134e+20  Dulce Rodriguez 2015-06-24 18:25:59  2015
#
# [2452772 rows x 4 columns]

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
usuariosG['time'].dt.year.value_counts()
# Out:
# time
# 2019    758344
# 2018    604516
# 2020    406586
# 2017    290991
# 2021    255151
# 2016     96284
# 2015     18274
# 2014      7021
# 2013      6211
# 2012      4097
# 2011      3241
# 2010      1608
# 2009       134
# 2008        93
# 2006        59
# 2007        53
# 2005        47
# 2004        32
# 2003        17
# 1990         6
# 2002         5
# 1999         1
# 2001         1
# Name: count, dtype: int64

# %%
plt.figure(figsize=(12,6))
sns.barplot(usuariosG['time'].dt.year.value_counts())
# Out:
# <Axes: xlabel='time', ylabel='count'>
