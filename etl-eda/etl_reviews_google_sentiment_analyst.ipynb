# %%
import pandas as pd
import os
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
ruta ='../extras/Google Maps/reviews-estados'

# %%
metadata_google = pd.read_json('../extras/Google Maps/bussiness_google.json.gz', compression='gzip')

# %% [markdown]
# Cargo los datasets de los estados seleccionados en uno unico

# %%
estados = ['California', 'New_Jersey', 'Florida', 'Illinois']  # Datasets usados para el estudio

df_states = pd.DataFrame()

for estado in estados:
    ruta_archivo = f'{ruta}/review-{estado}/all_{estado}.parquet'
    review_estado = pd.read_parquet(ruta_archivo)

    # Agrega la columna 'state' con el valor del estado actual
    review_estado['state'] = estado

    df_states = pd.concat([df_states, review_estado], ignore_index=True)

# df_states ahora contiene la concatenación de todos los DataFrames de los diferentes estados, con la columna 'state' agregada

# %% [markdown]
# Normalizo un estado

# %%
df_states['state'].replace('New_Jersey','New Jersey',inplace=True)

# %%
df_states.head()
# Out:
#         user_id           name                    time  rating  \
# 0  1.089912e+20        Song Ro 2021-01-06 05:12:07.056       5
# 1  1.112903e+20    Rafa Robles 2021-02-09 05:47:28.663       5
# 2  1.126404e+20      David Han 2020-03-08 05:04:42.296       4
# 3  1.174403e+20    Anthony Kim 2019-03-07 05:56:56.355       5
# 4  1.005808e+20  Mario Marzouk 2017-05-16 05:01:41.933       5
#
#                                                text  pics  \
# 0                      Love there korean rice cake.  None
# 1                                    Good very good  None
# 2  They make Korean traditional food very properly.  None
# 3                    Short ribs are very delicious.  None
# 4      Great food and prices the portions are large  None
#
#                                  gmap_id resp_time resp_text       state
# 0  0x80c2c778e3b73d33:0xbdc58662a4a97d49       NaT      None  California
# 1  0x80c2c778e3b73d33:0xbdc58662a4a97d49       NaT      None  California
# 2  0x80c2c778e3b73d33:0xbdc58662a4a97d49       NaT      None  California
# 3  0x80c2c778e3b73d33:0xbdc58662a4a97d49       NaT      None  California
# 4  0x80c2c778e3b73d33:0xbdc58662a4a97d49       NaT      None  California

# %% [markdown]
# Elimino duplicados en user_id time y gmap_id en conjunto

# %%
df_states.drop_duplicates(subset=['user_id','time','gmap_id'],inplace=True)

# %% [markdown]
# Elimino la columna pics que no sera usada

# %%
df_states.drop(columns='pics',inplace=True)

# %%
df_states.sample(5)
# Out:
#               user_id              name                    time  rating  \
# 3062262  1.183387e+20        john spond 2019-07-30 20:43:33.112       5
# 9521039  1.077940e+20  Craig Friedinger 2020-01-23 04:44:40.496       5
# 2174676  1.118758e+20     Clara Landers 2019-06-23 22:50:09.913       4
# 348102   1.044098e+20         Angry Son 2019-05-16 05:28:52.536       5
# 6688469  1.136236e+20          Kim Boff 2020-12-15 21:29:19.730       5
#
#                                                       text  \
# 3062262  It's right by home. I fill up there once a wee...
# 9521039                                               None
# 2174676  Ok do not like where it's at, but they do good...
# 348102                                                None
# 6688469                                               None
#
#                                        gmap_id resp_time resp_text       state
# 3062262  0x89c3c49d5c0fb3e7:0x853600658f48534e       NaT      None  New Jersey
# 9521039  0x880af5c608de0a99:0x6d065876dda0fb2b       NaT      None    Illinois
# 2174676  0x808fc09c71f8f77f:0x522c2121da1d7053       NaT      None  California
# 348102   0x80c2bf51ea454bad:0x425d1c2aefdbdf0c       NaT      None  California
# 6688469  0x88e634df665a5d2f:0xfb8749b27ecc44a0       NaT      None     Florida

# %% [markdown]
# Convierto la fecha a time

# %%
df_states.rename(columns={'time':'date'},inplace=True)
df_states['date'] = df_states['date'].dt.strftime('%Y-%m-%d %H:%M:%S')
df_states.rename(columns={'resp_time':'resp_date'},inplace=True)

# %% [markdown]
# ### Hago una cruza con la data de los sitios de google para ver las reviews de restaurantes

# %%
metadata_google.sample(5)
# Out:
#                                       gmap_id   latitude   longitude  \
# 561869  0x880efaa568aead21:0x3e2d5fb76aabc66c  41.756741  -88.313597
# 508017  0x880fd1da3785db0b:0x2f7bc5535f5c4f90  37.799176 -121.054085
# 466224  0x80e83a98026879e3:0x9e99e3c29af5a66e  34.181355 -118.882950
# 321668  0x80d95546b1621de9:0x2d76cf4fa1725b80  32.744512 -117.160712
# 522352  0x880e2cab525c5419:0xad0eb9511189e54b  41.895164  -87.623028
#
#                                                  category  stars  \
# 561869                                     ['Restaurant']    3.3
# 508017                                     ['Restaurant']    5.0
# 466224  ['Seafood restaurant' 'American restaurant' 'A...    2.7
# 321668                                     ['Restaurant']    4.9
# 522352                ['American restaurant' 'Bar' 'Pub']    4.4
#
#                               name       state
# 561869  Las Islas Marias De Aurora    Illinois
# 508017        Fireball Pizza Truck  California
# 466224                 Red Lobster  California
# 321668                  La Taverna  California
# 522352           Elephant & Castle    Illinois

# %%
metadata_google[['gmap_id','category']]
# Out:
#                                       gmap_id  \
# 4       0x88db4147b1d9e6f3:0x943dbd10a92ba1b1
# 5       0x88c2e4e34f1ed783:0x76c5da381c499d79
# 46      0x8890b9241e704667:0x3a1e565c17c00993
# 81      0x88e635378f43352f:0xa1b53c63436fa428
# 156     0x88d9ab98b5baad79:0x1a2e3f0642a55246
# ...                                       ...
# 693466  0x89c3b2b8e9c8c357:0xb1b07826ef85a598
# 693471  0x89c24d60acc3ffff:0xc8048546518281f6
# 693475  0x89c24d7a198a3541:0x3dcb8f429c053248
# 693478  0x89c3b290dcc12d6d:0x34ad59938efed577
# 693485    0x89c17b3b65b4680d:0x40a43d960a97a0
#
#                                                  category
# 4                                          ['Restaurant']
# 5                                   ['Buffet restaurant']
# 46                                         ['Restaurant']
# 81      ['Gas station' 'ATM' 'Convenience store' 'Rest...
# 156                                ['Mexican restaurant']
# ...                                                   ...
# 693466    ['Bar' 'Italian restaurant' 'Pub' 'Restaurant']
# 693471                 ['Restaurant' 'Family restaurant']
# 693475                            ['American restaurant']
# 693478  ['Latin American restaurant' 'Mexican restaura...
# 693485  ['Pizza restaurant' 'Italian restaurant' 'Pizz...
#
# [54906 rows x 2 columns]

# %% [markdown]
# Encuentro las review que por gmap_id pertenezcan a los locales de restaurante.

# %%
df_states = df_states[df_states['gmap_id'].isin(metadata_google['gmap_id'])]

# %% [markdown]
# ## Analisis de sentimiento usando TextBlob

# %%
from textblob import TextBlob

# %%
df_states['sentiment_textblob'] = df_states['text'].apply(lambda x:0 if x is None else TextBlob(x).sentiment.polarity)
df_states['sentiment_textblob_resp'] = df_states['resp_text'].apply(lambda x:0 if x is None else TextBlob(x).sentiment.polarity)

# %% [markdown]
# Exploro y comparo ratings con score del sentimiento

# %%
df_states.sample(5)
# Out:
#               user_id             name                 date  rating  \
# 68408    1.178356e+20    Luis Barragan  2020-10-31 07:07:43       5
# 7826740  1.131410e+20  ellen stefanits  2019-07-25 15:30:58       5
# 8454240  1.144431e+20  Max Mroczkowski  2021-06-24 20:06:55       5
# 7838789  1.145706e+20         Kev 1253  2020-05-24 14:25:55       5
# 1310202  1.116675e+20      John Garcia  2017-05-08 20:34:27       1
#
#                                                       text  \
# 68408                                                 None
# 7826740                                               None
# 8454240  Best fried rice in the city. Make sure to get ...
# 7838789                                               None
# 1310202  I got the breaded fish tacos and they tasted l...
#
#                                        gmap_id resp_time resp_text  \
# 68408    0x80c336d43db2fbcd:0xb0357b8e2775d93f       NaT      None
# 7826740  0x880fcc90842cda71:0xed06f34a062a8f65       NaT      None
# 8454240  0x880fd22d565378db:0x151569f439632f53       NaT      None
# 7838789  0x880ee5b151a6dc7d:0xbcee9aeb2b2a8d6c       NaT      None
# 1310202  0x80c36622c42bb5fd:0xc8c8fffdbd830105       NaT      None
#
#               state  sentiment_textblob  sentiment_textblob_resp
# 68408    California              0.0000                      0.0
# 7826740    Illinois              0.0000                      0.0
# 8454240    Illinois              0.8125                      0.0
# 7838789    Illinois              0.0000                      0.0
# 1310202  California              0.0000                      0.0

# %%
df_states[df_states['sentiment_textblob']<0].sample(5)
# Out:
#               user_id               name                 date  rating  \
# 7469756  1.084714e+20      Osvaldo Lopez  2019-11-18 20:53:58       1
# 6252090  1.115745e+20            Florida  2020-03-08 03:28:27       5
# 4168213  1.066834e+20      Andrea Merino  2019-05-01 18:13:20       3
# 6193896  1.155862e+20  Anthony Cartagena  2019-09-23 02:33:25       1
# 5884416  1.082846e+20   Jackie St.George  2018-02-15 17:22:04       1
#
#                                                       text  \
# 7469756  (Translated by Google) The lousy service and t...
# 6252090  Off menu - The Bayside. Prime Rib piled high w...
# 4168213                    It's ok but a little expensive.
# 6193896  Horrible costumer service...Sad\nIf don't like...
# 5884416  We went on Valentine's Day. Despite the fact t...
#
#                                        gmap_id resp_time resp_text  \
# 7469756  0x88dd83e495ac3927:0x4aa1ff529526162a       NaT      None
# 6252090   0x88eb7c4460bf23a5:0xd7b0a47f7f7f246       NaT      None
# 4168213  0x89c2531ecd0f1beb:0xbbbb2efcad9bdce9       NaT      None
# 6193896  0x88def1abcc188757:0xa865e0d1a6a1d210       NaT      None
# 5884416  0x88c290186e7d21ff:0x9f4453666e9d71e0       NaT      None
#
#               state  sentiment_textblob  sentiment_textblob_resp
# 7469756     Florida           -0.062500                      0.0
# 6252090     Florida           -0.164141                      0.0
# 4168213  New Jersey           -0.062500                      0.0
# 6193896     Florida           -1.000000                      0.0
# 5884416     Florida           -0.098571                      0.0

# %% [markdown]
# ### Voy a generar el criterio que en el sentimiento se obtenga un valor cuantificable mas real, normalizando el ranting y sumandole al socre

# %%
df_states['sentiment'] = df_states['rating'] / 5. + df_states['sentiment_textblob']

# %%
df_states.sample(5)
# Out:
#               user_id                name                 date  rating  \
# 7370330  1.114002e+20    Robert DePrez jr  2019-08-10 15:01:56       2
# 1948645  1.049375e+20        Jamie Toelle  2015-02-08 02:08:36       5
# 5185394  1.142369e+20  Ladonna Lippincott  2021-03-09 21:11:47       4
# 6026130  1.056228e+20       Nateia Lazarz  2018-05-10 12:27:30       4
# 675358   1.138117e+20         Jay Casares  2012-01-28 20:15:34       5
#
#                                                       text  \
# 7370330       Its fast food, expectations aren't very high
# 1948645                                               None
# 5185394                                               None
# 6026130                                               None
# 675358   One of the best little bars I've been to.\nRem...
#
#                                        gmap_id resp_time resp_text  \
# 7370330  0x88c2be09855a30db:0x787b50d7d029b70b       NaT      None
# 1948645  0x80dd313a43846cc3:0x129019255c97a1e4       NaT      None
# 5185394  0x88db47c5edc27223:0xef209fd63c769776       NaT      None
# 6026130  0x88d9ac5ec941a141:0xe40bf80fe06f9334       NaT      None
# 675358   0x80952f64b086cf09:0x55bf7bfbedf25f26       NaT      None
#
#               state  sentiment_textblob  sentiment_textblob_resp  sentiment
# 7370330     Florida            0.204000                      0.0   0.604000
# 1948645  California            0.000000                      0.0   1.000000
# 5185394     Florida            0.000000                      0.0   0.800000
# 6026130     Florida            0.000000                      0.0   0.800000
# 675358   California            0.270833                      0.0   1.270833

# %% [markdown]
# ### En base al valor obtenido defijo el criterio de <br>
#  para score ponderado mayor a 1.5 en un sentimiento muy bueno y asigno 2, <br>
#  Para score ponderado mayor a 1 y menor a 1.5 en un sentimiento bueno y asigno 1,<br>
#  Para score ponderado menor a 0.3 es un score negativo y asigno -1,<br>
#  Para score ponderado entre 1 y 0.3 es un score neutro y asigno 0

# %%
df_states['sentiment'] = df_states['sentiment'].apply(lambda x: 2 if x >= 1.5 else (1 if x >= 1 else (-1 if x <= 0.3 else 0)))

# %%
df_states.head()
# Out:
#         user_id           name                 date  rating  \
# 0  1.089912e+20        Song Ro  2021-01-06 05:12:07       5
# 1  1.112903e+20    Rafa Robles  2021-02-09 05:47:28       5
# 2  1.126404e+20      David Han  2020-03-08 05:04:42       4
# 3  1.174403e+20    Anthony Kim  2019-03-07 05:56:56       5
# 4  1.005808e+20  Mario Marzouk  2017-05-16 05:01:41       5
#
#                                                text  \
# 0                      Love there korean rice cake.
# 1                                    Good very good
# 2  They make Korean traditional food very properly.
# 3                    Short ribs are very delicious.
# 4      Great food and prices the portions are large
#
#                                  gmap_id resp_time resp_text       state  \
# 0  0x80c2c778e3b73d33:0xbdc58662a4a97d49       NaT      None  California
# 1  0x80c2c778e3b73d33:0xbdc58662a4a97d49       NaT      None  California
# 2  0x80c2c778e3b73d33:0xbdc58662a4a97d49       NaT      None  California
# 3  0x80c2c778e3b73d33:0xbdc58662a4a97d49       NaT      None  California
# 4  0x80c2c778e3b73d33:0xbdc58662a4a97d49       NaT      None  California
#
#    sentiment_textblob  sentiment_textblob_resp  sentiment
# 0            0.500000                      0.0          2
# 1            0.805000                      0.0          2
# 2            0.000000                      0.0          0
# 3            0.500000                      0.0          2
# 4            0.507143                      0.0          2

# %% [markdown]
# Elimino las columnas que ya no se usan debido al analisis de sentimiento

# %%
df_states.drop(columns=['sentiment_textblob','text','resp_text','rating'],inplace=True)

# %%
df_states.head()
# Out:
#         user_id           name                 date  \
# 0  1.089912e+20        Song Ro  2021-01-06 05:12:07
# 1  1.112903e+20    Rafa Robles  2021-02-09 05:47:28
# 2  1.126404e+20      David Han  2020-03-08 05:04:42
# 3  1.174403e+20    Anthony Kim  2019-03-07 05:56:56
# 4  1.005808e+20  Mario Marzouk  2017-05-16 05:01:41
#
#                                  gmap_id resp_time       state  \
# 0  0x80c2c778e3b73d33:0xbdc58662a4a97d49       NaT  California
# 1  0x80c2c778e3b73d33:0xbdc58662a4a97d49       NaT  California
# 2  0x80c2c778e3b73d33:0xbdc58662a4a97d49       NaT  California
# 3  0x80c2c778e3b73d33:0xbdc58662a4a97d49       NaT  California
# 4  0x80c2c778e3b73d33:0xbdc58662a4a97d49       NaT  California
#
#    sentiment_textblob_resp  sentiment
# 0                      0.0          2
# 1                      0.0          2
# 2                      0.0          0
# 3                      0.0          2
# 4                      0.0          2

# %% [markdown]
# ### Por último exporto el dataset a parquet particionado por estados

# %%
df_states.to_parquet('../datasets/processed/google/reviews_google.parquet.gz', compression='gzip')
